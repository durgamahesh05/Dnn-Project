# %% [markdown]
# # ResNet50V2 — Edible Plants (62 Classes)
# > Works on **Google Colab** and **Local Jupyter**
# > Models saved permanently — auto-uploaded to Drive from local

# %%
import sys, os, gc, random, shutil
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import (EarlyStopping, ReduceLROnPlateau,
                                         ModelCheckpoint)
from sklearn.metrics import (classification_report, confusion_matrix,
                              accuracy_score, precision_score,
                              recall_score, f1_score)
import seaborn as sns

SEED = 42
random.seed(SEED); np.random.seed(SEED); tf.random.set_seed(SEED)

# ── Environment detection ─────────────────────────────────────────────────
IS_COLAB = 'google.colab' in sys.modules
print(f"Environment : {'Google Colab' if IS_COLAB else 'Local (Jupyter)'}")
print(f"TF version  : {tf.__version__}")
print(f"GPU         : {tf.config.list_physical_devices('GPU')}")
# Out:
# Environment : Google Colab
# TF version  : 2.19.0
# GPU         : [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# ── Storage setup (works on both Colab and Localhost) ─────────────────────
IS_COLAB = 'google.colab' in sys.modules

if IS_COLAB:
    from google.colab import drive
    drive.mount('/content/drive')
    DRIVE_DIR  = '/content/drive/MyDrive/edible_plants_models'
    DATA_ROOT  = '/content/plant_data'
else:
    # Local: save models in the project folder next to this notebook
    import pathlib
    PROJECT_DIR = str(pathlib.Path.cwd())
    DRIVE_DIR   = os.path.join(PROJECT_DIR, 'saved_models')
    DATA_ROOT   = os.path.join(PROJECT_DIR, 'plant_data')

os.makedirs(DRIVE_DIR, exist_ok=True)
os.makedirs(DATA_ROOT, exist_ok=True)

TRAIN_DIR = os.path.join(DATA_ROOT, 'train')
VAL_DIR   = os.path.join(DATA_ROOT, 'val')
TEST_DIR  = os.path.join(DATA_ROOT, 'test')

print(f"Model save dir : {DRIVE_DIR}")
print(f"Data root      : {DATA_ROOT}")
# Out:
# Mounted at /content/drive
# Model save dir : /content/drive/MyDrive/edible_plants_models
# Data root      : /content/plant_data

# %%
# !pip install kagglehub -q
import kagglehub

path = kagglehub.dataset_download("gverzea/edible-wild-plants")
print("Dataset path:", path)
# Out:
# Using Colab cache for faster access to the 'edible-wild-plants' dataset.
# Dataset path: /kaggle/input/edible-wild-plants

# %%
def find_class_root(base):
    for root, dirs, files in os.walk(base):
        if len(dirs) > 50:
            sample = os.path.join(root, dirs[0])
            if os.path.isdir(sample):
                imgs = [f for f in os.listdir(sample)
                        if f.lower().endswith(('.jpg','.jpeg','.png'))]
                if imgs: return root
    return None

SOURCE_DIR = find_class_root(path)
if SOURCE_DIR is None:
    raise RuntimeError("Cannot find class root — re-run dataset download")

GOOD_FOLDERS = [d for d in sorted(os.listdir(SOURCE_DIR))
                if os.path.isdir(os.path.join(SOURCE_DIR, d))
                and any(f.lower().endswith(('.jpg','.jpeg','.png'))
                        for f in os.listdir(os.path.join(SOURCE_DIR, d)))]
print(f"SOURCE_DIR         : {SOURCE_DIR}")
print(f"Valid class folders: {len(GOOD_FOLDERS)}")
# Out:
# SOURCE_DIR         : /kaggle/input/edible-wild-plants/datasets/dataset
# Valid class folders: 62

# %%
# Only rebuild if train folder doesn't exist or is empty
if not os.path.exists(TRAIN_DIR) or len(os.listdir(TRAIN_DIR)) == 0:
    if os.path.exists(DATA_ROOT):
        shutil.rmtree(DATA_ROOT)
    os.makedirs(DATA_ROOT)

    def make_split(source, base, classes, seed=42, train_r=0.80, val_r=0.10):
        random.seed(seed); skipped = []
        for cls in classes:
            src = os.path.join(source, cls)
            imgs = [f for f in os.listdir(src)
                    if f.lower().endswith(('.jpg','.jpeg','.png'))
                    and os.path.isfile(os.path.join(src, f))]
            if len(imgs) < 5: skipped.append(cls); continue
            random.shuffle(imgs)
            n_tr = int(len(imgs) * train_r)
            n_v  = max(int(len(imgs) * val_r), 1)
            for dest, flist in [
                (os.path.join(base,'train',cls), imgs[:n_tr]),
                (os.path.join(base,'val',  cls), imgs[n_tr:n_tr+n_v]),
                (os.path.join(base,'test', cls), imgs[n_tr+n_v:])
            ]:
                os.makedirs(dest, exist_ok=True)
                for f in flist:
                    shutil.copy2(os.path.join(src, f), os.path.join(dest, f))
        return skipped

    print("Creating 80/10/10 split …")
    skipped = make_split(SOURCE_DIR, DATA_ROOT, GOOD_FOLDERS)
    if skipped: print(f"Skipped (too few images): {skipped}")
else:
    print("Split already exists — skipping rebuild.")

for split, d in [('train',TRAIN_DIR),('val',VAL_DIR),('test',TEST_DIR)]:
    if os.path.exists(d):
        nc = len([c for c in os.listdir(d) if os.path.isdir(os.path.join(d,c))])
        ni = sum(len(os.listdir(os.path.join(d,c)))
                 for c in os.listdir(d) if os.path.isdir(os.path.join(d,c)))
        print(f"  {split}: {nc} classes, {ni} images")
# Out:
# Creating 80/10/10 split …
#   train: 62 classes, 5246 images
#   val: 62 classes, 655 images
#   test: 62 classes, 657 images

# %%
IMG_SIZE = (224, 224); BATCH_SIZE = 8; SEED = 42
tf.keras.backend.clear_session(); gc.collect()
from tensorflow.keras.applications.resnet_v2 import preprocess_input
train_gen = ImageDataGenerator(preprocessing_function=preprocess_input,
    rotation_range=30, width_shift_range=0.15, height_shift_range=0.15,
    shear_range=0.15, zoom_range=0.2, horizontal_flip=True,
    brightness_range=[0.8,1.2], fill_mode='nearest')
vt_gen = ImageDataGenerator(preprocessing_function=preprocess_input)
train_ds = train_gen.flow_from_directory(TRAIN_DIR, target_size=IMG_SIZE,
    batch_size=BATCH_SIZE, class_mode='categorical', seed=SEED, shuffle=True)
val_ds   = vt_gen.flow_from_directory(VAL_DIR, target_size=IMG_SIZE,
    batch_size=BATCH_SIZE, class_mode='categorical', seed=SEED, shuffle=False)
test_ds  = vt_gen.flow_from_directory(TEST_DIR, target_size=IMG_SIZE,
    batch_size=BATCH_SIZE, class_mode='categorical', seed=SEED, shuffle=False)
classes = list(train_ds.class_indices.keys()); NUM_CLASSES = len(classes)
STEPS    = max(int(np.ceil(train_ds.samples / BATCH_SIZE)), 1)
VAL_STP  = max(int(np.ceil(val_ds.samples   / BATCH_SIZE)), 1)
TEST_STP = max(int(np.ceil(test_ds.samples  / BATCH_SIZE)), 1)
print(f"Classes:{NUM_CLASSES}  Train:{train_ds.samples}  Val:{val_ds.samples}  Test:{test_ds.samples}")
# Out:
# Found 5246 images belonging to 62 classes.
# Found 655 images belonging to 62 classes.
# Found 657 images belonging to 62 classes.
# Classes:62  Train:5246  Val:655  Test:657

# %%
tf.keras.backend.clear_session(); gc.collect()
base_model = tf.keras.applications.ResNet50V2(input_shape=(*IMG_SIZE,3),
    include_top=False, weights='imagenet')
base_model.trainable = False
inp = layers.Input(shape=(*IMG_SIZE,3))
x = base_model(inp, training=False)
x = layers.GlobalAveragePooling2D()(x); x = layers.BatchNormalization()(x)
x = layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(1e-4))(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(1e-4))(x)
x = layers.Dropout(0.4)(x)
out = layers.Dense(NUM_CLASSES, activation='softmax')(x)
model = models.Model(inp, out); model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94668760/94668760 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ resnet50v2 (Functional)         │ (None, 7, 7, 2048)     │    23,564,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 2048)           │         8,192 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     1,049,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 62)             │        15,934 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 24,769,342 (94.49 MB)
#  Trainable params: 1,200,446 (4.58 MB)
#  Non-trainable params: 23,568,896 (89.91 MB)

# %%
P1_CKPT    = os.path.join(DRIVE_DIR, 'ResNet50_phase1_best.weights.h5')
FINAL_PATH = os.path.join(DRIVE_DIR, 'ResNet50_edible_plants.keras')
model.compile(optimizer=tf.keras.optimizers.Adam(1e-3),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=['accuracy', tf.keras.metrics.AUC(name='auc'),
             tf.keras.metrics.Precision(name='precision'),
             tf.keras.metrics.Recall(name='recall')])
cb_p1 = [EarlyStopping(monitor='val_accuracy', patience=8, restore_best_weights=True, verbose=1),
         ReduceLROnPlateau(monitor='val_loss', factor=0.4, patience=3, min_lr=1e-7, verbose=1),
         ModelCheckpoint(P1_CKPT, monitor='val_accuracy',
                         save_best_only=True, save_weights_only=True, verbose=1)]
print(f"Phase 1 checkpoint -> {P1_CKPT}")
print("=== Phase 1: Head training (base FROZEN) ===")
h1 = model.fit(train_ds, epochs=25, steps_per_epoch=STEPS,
               validation_data=val_ds, validation_steps=VAL_STP,
               callbacks=cb_p1, verbose=1)
print(f"Phase 1 best val_accuracy: {max(h1.history['val_accuracy']):.4f}")
gc.collect()
# Out:
# Phase 1 checkpoint -> /content/drive/MyDrive/edible_plants_models/ResNet50_phase1_best.weights.h5
# === Phase 1: Head training (base FROZEN) ===
# Epoch 1/25
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.2552 - auc: 0.7530 - loss: 3.7757 - precision: 0.7222 - recall: 0.1520
# Epoch 1: val_accuracy improved from None to 0.42901, saving model to /content/drive/MyDrive/edible_plants_models/ResNet50_phase1_best.weights.h5
#
# Epoch 1: finished saving model to /content/drive/MyDrive/edible_plants_models/ResNet50_phase1_best.weights.h5
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 130s 176ms/step - accuracy: 0.3050 - auc: 0.8002 - loss: 3.4835 - precision: 0.8025 - recall: 0.1805 - val_accuracy: 0.4290 - val_auc: 0.9108 - val_loss: 2.8809 - val_precision: 0.9432 - val_recall: 0.2534 - learning_rate: 0.0010
# Epoch 2/25
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.3780 - auc: 0.8643 - loss: 3.1513 - precision: 0.8508 - recall: 0.2281
# Epoch 2: val_accuracy improved from 0.42901 to 0.48244, saving model to /content/drive/MyDrive/edible_plants_models/ResNet50_phase1_best.weights.h5
#
# Epoch 2: finished saving model to /content/drive/MyDrive/edible_plants_models/ResNet50_phase1_best.weights.h5
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 98s 149ms/step - accuracy: 0.3748 - auc: 0.8642 - loss: 3.1718 - precision: 0.8307 - recall: 0.2236 - val_accuracy: 0.4824 - val_auc: 0.9372 - val_loss: 2.7018 - val_precision: 0.9071 - val_recall: 0.3130 - learning_rate: 0.0010
# Epoch 3/25
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.3954 - auc: 0.8900 - loss: 3.0585 - precision: 0.8236 - recall: 0.2361
# Epoch 3: val_accuracy improved from 0.48244 to 0.51145, saving model to /content/drive/MyDrive/edible_plants_models/ResNet50_phase1_best.weights.h5
#
# Epoch 3: finished saving model to /content/drive/MyDrive/edible_plants_models/ResNet50_phase1_best.weights.h5
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 145s 154ms/step - accuracy: 0.4037 - auc: 0.8920 - loss: 3.0539 - precision: 0.8334 - recall: 0.2432 - val_accuracy: 0.5115 - val_auc: 0.9437 - val_loss: 2.6710 - val_precision: 0.8761 - val_recall: 0.2916 - learning_rate: 0.0010
# Epoch 4/25
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.4212 - auc: 0.9085 - loss: 2.9762 - precision: 0.8255 - recall: 0.2550
# Epoch 4: val_accuracy improved from 0.51145 to 0.55878, saving model to /content/drive/MyDrive/edible_plants_models/ResNet50_phase1_best.weights.h5
#
# Epoch 4: finished saving model to /content/drive/MyDrive/edible_plants_models/ResNet50_phase1_best.weights.h5
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 100s 153ms/step - accuracy: 0.4260 - auc: 0.9087 - loss: 2.9721 - precision: 0.8343 - recall: 0.2562 - val_accuracy: 0.5588 - val_auc: 0.9590 - val_loss: 2.5199 - val_precision: 0.9079 - val_recall: 0.3160 - learning_rate: 0.0010
# Epoch 5/25
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.4607 - auc: 0.9208 - loss: 2.8744 - precision: 0.8434 - recall: 0.2915
# Epoch 5: val_accuracy improved from 0.55878 to 0.56183, saving model to /content/drive/MyDrive/edible_plants_models/ResNet50_phase1_best.weights.h5
#
# Epoch 5: finished saving model to /content/drive/MyDrive/edible_plants_models/ResNet50_phase1_best.weights.h5
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 99s 151ms/step - accuracy: 0.4459 - auc: 0.9193 - loss: 2.9137 - precision: 0.8374 - recall: 0.2749 - val_accuracy: 0.5618 - val_auc: 0.9620 - val_loss: 2.5133 - val_precision: 0.9040 - val_recall: 0.3450 - learning_rate: 0.0010
# Epoch 6/25
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.4743 - auc: 0.9287 - loss: 2.8388 - precision: 0.8269 - recall: 0.2941
# Epoch 6: val_accuracy improved from 0.56183 to 0.58168, saving model to /content/drive/MyDrive/edible_plants_models/ResNet50_phase1_best.weights.h5
#
# Epoch 6: finished saving model to /content/drive/MyDrive/edible_plants_models/ResNet50_phase1_best.weights.h5
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 102s 156ms/step - accuracy: 0.4628 - auc: 0.9242 - loss: 2.8978 - precision: 0.8236 - recall: 0.2848 - val_accuracy: 0.5817 - val_auc: 0.9669 - val_loss: 2.4799 - val_precision: 0.8908 - val_recall: 0.3863 - learning_rate: 0.0010
# Epoch 7/25
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.4627 - auc: 0.9257 - loss: 2.9125 - precision: 0.8225 - recall: 0.2857
# Epoch 7: val_accuracy improved from 0.58168 to 0.60153, saving model to /content/drive/MyDrive/edible_plants_models/ResNet50_phase1_best.weights.h5
#
# Epoch 7: finished saving model to /content/drive/MyDrive/edible_plants_models/ResNet50_phase1_best.weights.h5
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 103s 157ms/step - accuracy: 0.4602 - auc: 0.9246 - loss: 2.9241 - precision: 0.8159 - recall: 0.2831 - val_accuracy: 0.6015 - val_auc: 0.9627 - val_loss: 2.5172 - val_precision: 0.8988 - val_recall: 0.3527 - learning_rate: 0.0010
# Epoch 8/25
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.4831 - auc: 0.9363 - loss: 2.8499 - precision: 0.8361 - recall: 0.3011
# Epoch 8: val_accuracy did not improve from 0.60153
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 105s 159ms/step - accuracy: 0.4705 - auc: 0.9321 - loss: 2.8902 - precision: 0.8273 - recall: 0.2932 - val_accuracy: 0.5939 - val_auc: 0.9640 - val_loss: 2.5482 - val_precision: 0.8937 - val_recall: 0.3466 - learning_rate: 0.0010
# Epoch 9/25
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.4986 - auc: 0.9417 - loss: 2.8098 - precision: 0.8383 - recall: 0.3212
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0004000000189989805.
#
# Epoch 9: val_accuracy did not improve from 0.60153
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 100s 153ms/step - accuracy: 0.4910 - auc: 0.9368 - loss: 2.8592 - precision: 0.8294 - recall: 0.3113 - val_accuracy: 0.5878 - val_auc: 0.9611 - val_loss: 2.5573 - val_precision: 0.8938 - val_recall: 0.3725 - learning_rate: 0.0010
# Epoch 10/25
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.5177 - auc: 0.9461 - loss: 2.7577 - precision: 0.8568 - recall: 0.3258
# Epoch 10: val_accuracy improved from 0.60153 to 0.62137, saving model to /content/drive/MyDrive/edible_plants_models/ResNet50_phase1_best.weights.h5
#
# Epoch 10: finished saving model to /content/drive/MyDrive/edible_plants_models/ResNet50_phase1_best.weights.h5
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 101s 154ms/step - accuracy: 0.5246 - auc: 0.9478 - loss: 2.7382 - precision: 0.8594 - recall: 0.3357 - val_accuracy: 0.6214 - val_auc: 0.9702 - val_loss: 2.4503 - val_precision: 0.8881 - val_recall: 0.3878 - learning_rate: 4.0000e-04
# Epoch 11/25
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.5291 - auc: 0.9516 - loss: 2.7003 - precision: 0.8686 - recall: 0.3450
# Epoch 11: val_accuracy improved from 0.62137 to 0.62748, saving model to /content/drive/MyDrive/edible_plants_models/ResNet50_phase1_best.weights.h5
#
# Epoch 11: finished saving model to /content/drive/MyDrive/edible_plants_models/ResNet50_phase1_best.weights.h5
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 102s 155ms/step - accuracy: 0.5408 - auc: 0.9523 - loss: 2.6778 - precision: 0.8591 - recall: 0.3521 - val_accuracy: 0.6275 - val_auc: 0.9689 - val_loss: 2.4248 - val_precision: 0.8870 - val_recall: 0.4076 - learning_rate: 4.0000e-04
# Epoch 12/25
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.5318 - auc: 0.9510 - loss: 2.6956 - precision: 0.8528 - recall: 0.3431
# Epoch 12: val_accuracy improved from 0.62748 to 0.63969, saving model to /content/drive/MyDrive/edible_plants_models/ResNet50_phase1_best.weights.h5
#
# Epoch 12: finished saving model to /content/drive/MyDrive/edible_plants_models/ResNet50_phase1_best.weights.h5
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 102s 155ms/step - accuracy: 0.5463 - auc: 0.9517 - loss: 2.6610 - precision: 0.8539 - recall: 0.3542 - val_accuracy: 0.6397 - val_auc: 0.9745 - val_loss: 2.3714 - val_precision: 0.9218 - val_recall: 0.4137 - learning_rate: 4.0000e-04
# Epoch 13/25
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.5578 - auc: 0.9575 - loss: 2.5821 - precision: 0.8536 - recall: 0.3738
# Epoch 13: val_accuracy improved from 0.63969 to 0.64580, saving model to /content/drive/MyDrive/edible_plants_models/ResNet50_phase1_best.weights.h5
#
# Epoch 13: finished saving model to /content/drive/MyDrive/edible_plants_models/ResNet50_phase1_best.weights.h5
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 103s 157ms/step - accuracy: 0.5574 - auc: 0.9578 - loss: 2.5855 - precision: 0.8636 - recall: 0.3706 - val_accuracy: 0.6458 - val_auc: 0.9717 - val_loss: 2.3773 - val_precision: 0.8711 - val_recall: 0.4229 - learning_rate: 4.0000e-04
# Epoch 14/25
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.5647 - auc: 0.9601 - loss: 2.5600 - precision: 0.8752 - recall: 0.3807
# Epoch 14: val_accuracy did not improve from 0.64580
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 99s 151ms/step - accuracy: 0.5705 - auc: 0.9599 - loss: 2.5481 - precision: 0.8745 - recall: 0.3837 - val_accuracy: 0.6458 - val_auc: 0.9738 - val_loss: 2.3435 - val_precision: 0.8931 - val_recall: 0.4336 - learning_rate: 4.0000e-04
# Epoch 15/25
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.5762 - auc: 0.9628 - loss: 2.5355 - precision: 0.8695 - recall: 0.3889
# Epoch 15: val_accuracy improved from 0.64580 to 0.67023, saving model to /content/drive/MyDrive/edible_plants_models/ResNet50_phase1_best.weights.h5
#
# Epoch 15: finished saving model to /content/drive/MyDrive/edible_plants_models/ResNet50_phase1_best.weights.h5
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 100s 153ms/step - accuracy: 0.5761 - auc: 0.9617 - loss: 2.5233 - precision: 0.8768 - recall: 0.3921 - val_accuracy: 0.6702 - val_auc: 0.9759 - val_loss: 2.3117 - val_precision: 0.9106 - val_recall: 0.4198 - learning_rate: 4.0000e-04
# Epoch 16/25
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.5770 - auc: 0.9637 - loss: 2.4994 - precision: 0.8614 - recall: 0.3789
# Epoch 16: val_accuracy improved from 0.67023 to 0.67786, saving model to /content/drive/MyDrive/edible_plants_models/ResNet50_phase1_best.weights.h5
#
# Epoch 16: finished saving model to /content/drive/MyDrive/edible_plants_models/ResNet50_phase1_best.weights.h5
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 101s 154ms/step - accuracy: 0.5869 - auc: 0.9648 - loss: 2.4773 - precision: 0.8673 - recall: 0.3961 - val_accuracy: 0.6779 - val_auc: 0.9745 - val_loss: 2.2964 - val_precision: 0.9006 - val_recall: 0.4427 - learning_rate: 4.0000e-04
# Epoch 17/25
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.5919 - auc: 0.9650 - loss: 2.4747 - precision: 0.8708 - recall: 0.4016
# Epoch 17: val_accuracy improved from 0.67786 to 0.69008, saving model to /content/drive/MyDrive/edible_plants_models/ResNet50_phase1_best.weights.h5
#
# Epoch 17: finished saving model to /content/drive/MyDrive/edible_plants_models/ResNet50_phase1_best.weights.h5
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 100s 153ms/step - accuracy: 0.5968 - auc: 0.9660 - loss: 2.4599 - precision: 0.8721 - recall: 0.4043 - val_accuracy: 0.6901 - val_auc: 0.9756 - val_loss: 2.2519 - val_precision: 0.9065 - val_recall: 0.4443 - learning_rate: 4.0000e-04
# Epoch 18/25
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.5879 - auc: 0.9666 - loss: 2.4609 - precision: 0.8652 - recall: 0.4003
# Epoch 18: val_accuracy did not improve from 0.69008
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 98s 149ms/step - accuracy: 0.5947 - auc: 0.9679 - loss: 2.4424 - precision: 0.8758 - recall: 0.4072 - val_accuracy: 0.6855 - val_auc: 0.9748 - val_loss: 2.2898 - val_precision: 0.8663 - val_recall: 0.4351 - learning_rate: 4.0000e-04
# Epoch 19/25
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.6058 - auc: 0.9691 - loss: 2.4070 - precision: 0.8752 - recall: 0.4125
# Epoch 19: val_accuracy did not improve from 0.69008
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 142s 149ms/step - accuracy: 0.5936 - auc: 0.9672 - loss: 2.4311 - precision: 0.8709 - recall: 0.4102 - val_accuracy: 0.6687 - val_auc: 0.9737 - val_loss: 2.2855 - val_precision: 0.8892 - val_recall: 0.4290 - learning_rate: 4.0000e-04
# Epoch 20/25
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.6198 - auc: 0.9709 - loss: 2.3661 - precision: 0.8958 - recall: 0.4298
# Epoch 20: val_accuracy improved from 0.69008 to 0.69618, saving model to /content/drive/MyDrive/edible_plants_models/ResNet50_phase1_best.weights.h5
#
# Epoch 20: finished saving model to /content/drive/MyDrive/edible_plants_models/ResNet50_phase1_best.weights.h5
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 101s 154ms/step - accuracy: 0.6136 - auc: 0.9681 - loss: 2.3925 - precision: 0.8926 - recall: 0.4295 - val_accuracy: 0.6962 - val_auc: 0.9772 - val_loss: 2.2343 - val_precision: 0.9018 - val_recall: 0.4489 - learning_rate: 4.0000e-04
# Epoch 21/25
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.6019 - auc: 0.9694 - loss: 2.3913 - precision: 0.8786 - recall: 0.4234
# Epoch 21: val_accuracy did not improve from 0.69618
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 99s 151ms/step - accuracy: 0.6186 - auc: 0.9698 - loss: 2.3648 - precision: 0.8770 - recall: 0.4348 - val_accuracy: 0.6763 - val_auc: 0.9776 - val_loss: 2.2249 - val_precision: 0.8706 - val_recall: 0.4519 - learning_rate: 4.0000e-04
# Epoch 22/25
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.6295 - auc: 0.9728 - loss: 2.3280 - precision: 0.8806 - recall: 0.4494
# Epoch 22: val_accuracy did not improve from 0.69618
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 98s 150ms/step - accuracy: 0.6336 - auc: 0.9721 - loss: 2.3370 - precision: 0.8791 - recall: 0.4436 - val_accuracy: 0.6870 - val_auc: 0.9760 - val_loss: 2.2157 - val_precision: 0.9061 - val_recall: 0.4565 - learning_rate: 4.0000e-04
# Epoch 23/25
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.6141 - auc: 0.9708 - loss: 2.3567 - precision: 0.8841 - recall: 0.4225
# Epoch 23: val_accuracy did not improve from 0.69618
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 99s 151ms/step - accuracy: 0.6230 - auc: 0.9710 - loss: 2.3437 - precision: 0.8833 - recall: 0.4388 - val_accuracy: 0.6870 - val_auc: 0.9770 - val_loss: 2.1945 - val_precision: 0.8971 - val_recall: 0.4656 - learning_rate: 4.0000e-04
# Epoch 24/25
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.6385 - auc: 0.9728 - loss: 2.3016 - precision: 0.8888 - recall: 0.4546
# Epoch 24: val_accuracy did not improve from 0.69618
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 98s 149ms/step - accuracy: 0.6291 - auc: 0.9712 - loss: 2.3288 - precision: 0.8761 - recall: 0.4461 - val_accuracy: 0.6901 - val_auc: 0.9768 - val_loss: 2.1952 - val_precision: 0.8935 - val_recall: 0.4611 - learning_rate: 4.0000e-04
# Epoch 25/25
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.6260 - auc: 0.9738 - loss: 2.3120 - precision: 0.8824 - recall: 0.4432
# Epoch 25: val_accuracy did not improve from 0.69618
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 98s 149ms/step - accuracy: 0.6353 - auc: 0.9732 - loss: 2.3025 - precision: 0.8806 - recall: 0.4567 - val_accuracy: 0.6947 - val_auc: 0.9769 - val_loss: 2.1783 - val_precision: 0.8809 - val_recall: 0.4855 - learning_rate: 4.0000e-04
# Restoring model weights from the end of the best epoch: 20.
# Phase 1 best val_accuracy: 0.6962
# 2091

# %%
P2_CKPT = os.path.join(DRIVE_DIR, 'ResNet50_phase2_best.weights.h5')
model.load_weights(P1_CKPT)
base_model.trainable = True
for layer in base_model.layers:
    if isinstance(layer, layers.BatchNormalization): layer.trainable = False
for layer in base_model.layers[:-50]: layer.trainable = False
lr_schedule = tf.keras.optimizers.schedules.CosineDecay(
    initial_learning_rate=2e-5, decay_steps=max(STEPS*40,1), alpha=1e-7)
model.compile(optimizer=tf.keras.optimizers.Adam(lr_schedule),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.05),
    metrics=['accuracy', tf.keras.metrics.AUC(name='auc'),
             tf.keras.metrics.Precision(name='precision'),
             tf.keras.metrics.Recall(name='recall')])
cb_p2 = [EarlyStopping(monitor='val_accuracy', patience=12, restore_best_weights=True, verbose=1),
         ModelCheckpoint(P2_CKPT, monitor='val_accuracy',
                         save_best_only=True, save_weights_only=True, verbose=1)]
print(f"Phase 2 checkpoint -> {P2_CKPT}")
print("=== Phase 2: Fine-tuning top-50 base layers ===")
gc.collect()
h2 = model.fit(train_ds, epochs=10, steps_per_epoch=STEPS,
               validation_data=val_ds, validation_steps=VAL_STP,
               callbacks=cb_p2, verbose=1)
print(f"Phase 2 best val_accuracy: {max(h2.history['val_accuracy']):.4f}")
gc.collect()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 57 variables whereas the saved optimizer has 18 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Phase 2 checkpoint -> /content/drive/MyDrive/edible_plants_models/ResNet50_phase2_best.weights.h5
# === Phase 2: Fine-tuning top-50 base layers ===
# Epoch 1/10
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.6291 - auc: 0.9726 - loss: 2.0602 - precision: 0.8610 - recall: 0.4458
# Epoch 1: val_accuracy improved from None to 0.68397, saving model to /content/drive/MyDrive/edible_plants_models/ResNet50_phase2_best.weights.h5
#
# Epoch 1: finished saving model to /content/drive/MyDrive/edible_plants_models/ResNet50_phase2_best.weights.h5
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 132s 177ms/step - accuracy: 0.6390 - auc: 0.9717 - loss: 2.0363 - precision: 0.8635 - recall: 0.4653 - val_accuracy: 0.6840 - val_auc: 0.9790 - val_loss: 1.8841 - val_precision: 0.8673 - val_recall: 0.5389
# Epoch 2/10
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.6505 - auc: 0.9736 - loss: 1.9813 - precision: 0.8728 - recall: 0.5034
# Epoch 2: val_accuracy improved from 0.68397 to 0.72366, saving model to /content/drive/MyDrive/edible_plants_models/ResNet50_phase2_best.weights.h5
#
# Epoch 2: finished saving model to /content/drive/MyDrive/edible_plants_models/ResNet50_phase2_best.weights.h5
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 114s 174ms/step - accuracy: 0.6521 - auc: 0.9747 - loss: 1.9662 - precision: 0.8749 - recall: 0.5027 - val_accuracy: 0.7237 - val_auc: 0.9808 - val_loss: 1.8284 - val_precision: 0.8700 - val_recall: 0.5924
# Epoch 3/10
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.6768 - auc: 0.9765 - loss: 1.9025 - precision: 0.8750 - recall: 0.5290
# Epoch 3: val_accuracy improved from 0.72366 to 0.72519, saving model to /content/drive/MyDrive/edible_plants_models/ResNet50_phase2_best.weights.h5
#
# Epoch 3: finished saving model to /content/drive/MyDrive/edible_plants_models/ResNet50_phase2_best.weights.h5
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 113s 172ms/step - accuracy: 0.6653 - auc: 0.9767 - loss: 1.9260 - precision: 0.8728 - recall: 0.5219 - val_accuracy: 0.7252 - val_auc: 0.9821 - val_loss: 1.7758 - val_precision: 0.8831 - val_recall: 0.5649
# Epoch 4/10
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.6838 - auc: 0.9786 - loss: 1.8537 - precision: 0.8699 - recall: 0.5339
# Epoch 4: val_accuracy improved from 0.72519 to 0.74962, saving model to /content/drive/MyDrive/edible_plants_models/ResNet50_phase2_best.weights.h5
#
# Epoch 4: finished saving model to /content/drive/MyDrive/edible_plants_models/ResNet50_phase2_best.weights.h5
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 112s 170ms/step - accuracy: 0.6790 - auc: 0.9791 - loss: 1.8644 - precision: 0.8708 - recall: 0.5318 - val_accuracy: 0.7496 - val_auc: 0.9791 - val_loss: 1.7854 - val_precision: 0.8739 - val_recall: 0.6137
# Epoch 5/10
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.6957 - auc: 0.9801 - loss: 1.8263 - precision: 0.8839 - recall: 0.5550
# Epoch 5: val_accuracy did not improve from 0.74962
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 105s 161ms/step - accuracy: 0.6914 - auc: 0.9806 - loss: 1.8348 - precision: 0.8825 - recall: 0.5496 - val_accuracy: 0.7389 - val_auc: 0.9800 - val_loss: 1.7787 - val_precision: 0.8723 - val_recall: 0.6153
# Epoch 6/10
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.7113 - auc: 0.9816 - loss: 1.7977 - precision: 0.8898 - recall: 0.5584
# Epoch 6: val_accuracy did not improve from 0.74962
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 101s 154ms/step - accuracy: 0.7049 - auc: 0.9815 - loss: 1.8059 - precision: 0.8924 - recall: 0.5581 - val_accuracy: 0.7450 - val_auc: 0.9821 - val_loss: 1.7416 - val_precision: 0.8831 - val_recall: 0.6458
# Epoch 7/10
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.7052 - auc: 0.9818 - loss: 1.8010 - precision: 0.8783 - recall: 0.5615
# Epoch 7: val_accuracy did not improve from 0.74962
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 101s 154ms/step - accuracy: 0.7181 - auc: 0.9827 - loss: 1.7751 - precision: 0.8839 - recall: 0.5690 - val_accuracy: 0.7374 - val_auc: 0.9787 - val_loss: 1.7558 - val_precision: 0.8691 - val_recall: 0.6183
# Epoch 8/10
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.7311 - auc: 0.9845 - loss: 1.7177 - precision: 0.8871 - recall: 0.5935
# Epoch 8: val_accuracy did not improve from 0.74962
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 103s 157ms/step - accuracy: 0.7234 - auc: 0.9847 - loss: 1.7367 - precision: 0.8885 - recall: 0.5831 - val_accuracy: 0.7405 - val_auc: 0.9809 - val_loss: 1.7301 - val_precision: 0.8727 - val_recall: 0.6382
# Epoch 9/10
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.7397 - auc: 0.9865 - loss: 1.6966 - precision: 0.8983 - recall: 0.5877
# Epoch 9: val_accuracy improved from 0.74962 to 0.75725, saving model to /content/drive/MyDrive/edible_plants_models/ResNet50_phase2_best.weights.h5
#
# Epoch 9: finished saving model to /content/drive/MyDrive/edible_plants_models/ResNet50_phase2_best.weights.h5
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 108s 164ms/step - accuracy: 0.7385 - auc: 0.9874 - loss: 1.6886 - precision: 0.8963 - recall: 0.5949 - val_accuracy: 0.7573 - val_auc: 0.9813 - val_loss: 1.6836 - val_precision: 0.8665 - val_recall: 0.6641
# Epoch 10/10
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.7351 - auc: 0.9883 - loss: 1.6696 - precision: 0.8865 - recall: 0.5908
# Epoch 10: val_accuracy improved from 0.75725 to 0.76183, saving model to /content/drive/MyDrive/edible_plants_models/ResNet50_phase2_best.weights.h5
#
# Epoch 10: finished saving model to /content/drive/MyDrive/edible_plants_models/ResNet50_phase2_best.weights.h5
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 140s 161ms/step - accuracy: 0.7326 - auc: 0.9867 - loss: 1.6826 - precision: 0.8917 - recall: 0.5982 - val_accuracy: 0.7618 - val_auc: 0.9827 - val_loss: 1.6721 - val_precision: 0.8804 - val_recall: 0.6519
# Restoring model weights from the end of the best epoch: 10.
# Phase 2 best val_accuracy: 0.7618
# 1993

# %%
def combine(h1, h2, key): return h1.history.get(key,[]) + h2.history.get(key,[])
phase1_end = len(h1.history['accuracy'])
pairs = [('accuracy','val_accuracy','Accuracy'),('loss','val_loss','Loss'),
         ('auc','val_auc','AUC'),('precision','val_precision','Precision'),('recall','val_recall','Recall')]
fig, axes = plt.subplots(2, 3, figsize=(20,12))
for ax,(tr,vl,title) in zip(axes.flat, pairs):
    ax.plot(combine(h1,h2,tr), color='steelblue', lw=2, label='Train')
    ax.plot(combine(h1,h2,vl), color='coral',     lw=2, label='Val')
    ax.axvline(phase1_end, color='gray', linestyle='--', alpha=0.7, label='Fine-tune start')
    ax.set_title(f'ResNet50V2 — {title}', fontweight='bold'); ax.legend(); ax.grid(alpha=0.3)
ax_s = axes.flat[-1]; ax_s.axis('off')
ax_s.text(0.05,0.5, f"ResNet50V2 Summary\nP1: {max(h1.history['val_accuracy']):.4f}\nP2: {max(h2.history['val_accuracy']):.4f}\nBest: {max(combine(h1,h2,'val_accuracy')):.4f}",
    fontsize=12,family='monospace',verticalalignment='center',
    bbox=dict(boxstyle='round',facecolor='lightyellow',alpha=0.5))
plt.tight_layout(); plt.show()

# %%
print("Running streaming predictions on test set …")
y_pred_list = []; y_true_list = []
test_ds.reset()
for batch_x, batch_y in test_ds:
    preds = model.predict_on_batch(batch_x)
    y_pred_list.append(np.argmax(preds,   axis=1))
    y_true_list.append(np.argmax(batch_y, axis=1))
    if len(y_pred_list) >= TEST_STP: break
y_pred = np.concatenate(y_pred_list)
y_true = np.concatenate(y_true_list)
del y_pred_list, y_true_list; gc.collect()
n = min(len(y_pred), len(y_true)); y_pred, y_true = y_pred[:n], y_true[:n]

acc  = accuracy_score (y_true, y_pred)
prec = precision_score(y_true, y_pred, average='weighted', zero_division=0)
rec  = recall_score   (y_true, y_pred, average='weighted', zero_division=0)
f1   = f1_score       (y_true, y_pred, average='weighted', zero_division=0)
print(f"\n  Accuracy  : {acc:.4f}")
print(f"  Precision : {prec:.4f}")
print(f"  Recall    : {rec:.4f}")
print(f"  F1-Score  : {f1:.4f}")
print(f"  Grade     : {'EXCELLENT (>=90%)' if acc>=0.90 else 'GOOD (>=80%)' if acc>=0.80 else 'Needs tuning'}")
print("\n—— Classification Report ——")
print(classification_report(y_true, y_pred, labels=np.arange(len(classes)),
                             target_names=classes, zero_division=0))
# Out:
# Running streaming predictions on test set …
#
#   Accuracy  : 0.7489
#   Precision : 0.7646
#   Recall    : 0.7489
#   F1-Score  : 0.7420
#   Grade     : Needs tuning
#
# —— Classification Report ——
#                      precision    recall  f1-score   support
#
#             Alfalfa       0.50      0.20      0.29         5
#           Asparagus       0.78      0.70      0.74        10
#        Blue Vervain       0.75      0.60      0.67         5
#  Broadleaf Plantain       0.43      0.60      0.50         5
#        Bull Thistle       0.40      0.40      0.40         5
#             Cattail       0.62      1.00      0.77         5
#           Chickweed       0.65      0.73      0.69        15
#             Chicory       0.75      0.60      0.67         5
#            Cleavers       1.00      0.80      0.89         5
#           Coltsfoot       0.80      0.80      0.80         5
#  Common Sow Thistle       0.78      0.70      0.74        10
#       Common Yarrow       1.00      0.20      0.33         5
#          Coneflower       0.57      0.80      0.67         5
#    Creeping Charlie       0.62      0.50      0.56        10
#      Crimson Clover       0.80      0.80      0.80         5
#          Curly Dock       0.67      0.67      0.67        15
#      Daisy Fleabane       0.89      0.87      0.88        77
#          Dandellion       0.91      0.91      0.91       106
# Downy Yellow Violet       0.80      0.80      0.80         5
#          Elderberry       0.71      1.00      0.83        10
#    Evening Primrose       1.00      1.00      1.00         5
#    Fern Leaf Yarrow       1.00      1.00      1.00         5
#    Field Pennycress       0.67      0.60      0.63        10
#            Fireweed       0.44      0.80      0.57         5
#       Forget Me Not       0.80      0.80      0.80         5
#      Garlic Mustard       0.78      0.70      0.74        10
#            Harebell       0.83      1.00      0.91         5
#              Henbit       0.69      0.73      0.71        15
#         Herb Robert       1.00      0.20      0.33         5
#   Japanese Knotweed       0.00      0.00      0.00         5
#        Joe Pye Weed       0.50      0.80      0.62         5
#            Knapweed       1.00      0.60      0.75         5
#               Kudzu       0.60      0.60      0.60         5
#      Lambs Quarters       0.50      0.33      0.40        15
#              Mallow       0.67      0.40      0.50         5
#            Mayapple       0.67      0.80      0.73         5
#         Meadowsweet       1.00      0.20      0.33         5
#        Milk Thistle       0.62      1.00      0.77         5
#             Mullein       0.50      0.60      0.55         5
#   New England Aster       1.00      0.60      0.75         5
#      Partridgeberry       0.43      0.60      0.50         5
#         Peppergrass       0.64      0.47      0.54        15
#        Pickerelweed       0.67      0.80      0.73         5
#      Pineapple Weed       0.60      0.60      0.60         5
# Prickly Pear Cactus       0.83      1.00      0.91         5
#   Purple Deadnettle       0.70      0.70      0.70        10
#    Queen Annes Lace       0.50      0.60      0.55         5
#          Red Clover       1.00      0.60      0.75         5
#        Sheep Sorrel       0.50      0.20      0.29         5
#     Shepherds Purse       0.70      0.70      0.70        10
#       Spring Beauty       0.67      0.80      0.73         5
#           Sunflower       0.85      0.92      0.88        74
#     Supplejack Vine       1.00      0.40      0.57         5
#           Tea Plant       0.40      0.80      0.53         5
#              Teasel       0.75      0.60      0.67         5
#           Toothwort       0.64      0.70      0.67        10
#      Vervain Mallow       0.50      0.40      0.44         5
#       Wild Bee Balm       0.60      0.60      0.60         5
#   Wild Black Cherry       0.56      1.00      0.71         5
#     Wild Grape Vine       0.88      0.70      0.78        10
#           Wild Leek       0.73      0.80      0.76        10
#         Wood Sorrel       0.50      0.80      0.62         5
#
#            accuracy                           0.75       657
#           macro avg       0.70      0.66      0.65       657
#        weighted avg       0.76      0.75      0.74       657

# %%
cm  = confusion_matrix(y_true, y_pred, labels=np.arange(len(classes)))
fsz = max(10, len(classes)//2)
plt.figure(figsize=(fsz, fsz-2))
sns.heatmap(cm, annot=(len(classes)<=20), fmt='d',
            xticklabels=classes, yticklabels=classes, cmap='Greens')
plt.title('ResNet50V2 — Confusion Matrix', fontsize=14)
plt.ylabel('True Label'); plt.xlabel('Predicted Label')
plt.xticks(rotation=90, fontsize=7); plt.yticks(rotation=0, fontsize=7)
plt.tight_layout(); plt.show()
del y_pred, y_true; gc.collect()
# Out:
# 16524

# %%
model.save(FINAL_PATH)
print(f"Model saved: {FINAL_PATH}")
gc.collect(); tf.keras.backend.clear_session()
# Out:
# Model saved: /content/drive/MyDrive/edible_plants_models/ResNet50_edible_plants.keras

# %%
# ── Upload ALL saved files to Google Drive ────────────────────────────────
# Uploads: phase1 checkpoint, phase2 checkpoint, final .keras model
# Works from LOCAL machine only. Skipped automatically on Colab.
IS_COLAB = 'google.colab' in sys.modules

if IS_COLAB:
    print("Running on Colab — all files already saved to Drive. Nothing to upload.")
else:
    print("Running locally — uploading all files from saved_models/ to Google Drive …")
    try:
        import subprocess as _sp, sys as _sys
        _sp.check_call([_sys.executable, '-m', 'pip', 'install', 'pydrive2', '-q'])

        from pydrive2.auth import GoogleAuth
        from pydrive2.drive import GoogleDrive

        # One-time browser login (cached after first run)
        gauth = GoogleAuth()
        gauth.LocalWebserverAuth()
        gdrive = GoogleDrive(gauth)

        # Find or create 'edible_plants_models' folder in Drive root
        folder_list = gdrive.ListFile(
            {'q': "title='edible_plants_models' and "
                  "mimeType='application/vnd.google-apps.folder' and "
                  "trashed=false"}
        ).GetList()

        if folder_list:
            folder_id = folder_list[0]['id']
            print(f"Found Drive folder  : edible_plants_models (id={folder_id})")
        else:
            folder = gdrive.CreateFile({
                'title': 'edible_plants_models',
                'mimeType': 'application/vnd.google-apps.folder'
            })
            folder.Upload()
            folder_id = folder['id']
            print(f"Created Drive folder: edible_plants_models (id={folder_id})")

        # Upload every file inside DRIVE_DIR (saved_models/)
        all_files = [f for f in os.listdir(DRIVE_DIR)
                     if os.path.isfile(os.path.join(DRIVE_DIR, f))]

        if not all_files:
            print("No files found in saved_models/ — make sure training completed.")
        else:
            print(f"\nUploading {len(all_files)} file(s):")
            for fname in sorted(all_files):
                local_path = os.path.join(DRIVE_DIR, fname)
                size_mb = os.path.getsize(local_path) / (1024 * 1024)

                # Check if file already exists in Drive folder → update it
                existing = gdrive.ListFile(
                    {'q': f"title='{fname}' and '{folder_id}' in parents and trashed=false"}
                ).GetList()

                if existing:
                    gfile = existing[0]
                    gfile.SetContentFile(local_path)
                    gfile.Upload()
                    print(f"  Updated  {fname:50s}  ({size_mb:.1f} MB)")
                else:
                    gfile = gdrive.CreateFile({
                        'title': fname,
                        'parents': [{'id': folder_id}]
                    })
                    gfile.SetContentFile(local_path)
                    gfile.Upload()
                    print(f"  Uploaded {fname:50s}  ({size_mb:.1f} MB)")

            print("\nAll files uploaded to Drive/edible_plants_models/")
            print("Open modelcomparison.ipynb on Colab to compare all models.")

    except Exception as e:
        print(f"Auto-upload failed: {e}")
        print("\nManual option:")
        print(f"  Go to drive.google.com → My Drive")
        print(f"  Create folder 'edible_plants_models' if it doesn't exist")
        print(f"  Upload all files from: {DRIVE_DIR}")
# Out:
# Running on Colab — all files already saved to Drive. Nothing to upload.
