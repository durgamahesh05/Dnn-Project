# %% [markdown]
# # EfficientNetB0 — Edible Plants (62 Classes)
# > Works on **Google Colab** and **Local Jupyter** · Target ≥90%
# > Models saved permanently — auto-uploaded to Drive from local

# %%
import sys, os, gc, random, shutil
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import (EarlyStopping, ReduceLROnPlateau,
                                         ModelCheckpoint)
from sklearn.metrics import (classification_report, confusion_matrix,
                              accuracy_score, precision_score,
                              recall_score, f1_score)
import seaborn as sns

SEED = 42
random.seed(SEED); np.random.seed(SEED); tf.random.set_seed(SEED)

# ── Environment detection ─────────────────────────────────────────────────
IS_COLAB = 'google.colab' in sys.modules
print(f"Environment : {'Google Colab' if IS_COLAB else 'Local (Jupyter)'}")
print(f"TF version  : {tf.__version__}")
print(f"GPU         : {tf.config.list_physical_devices('GPU')}")
# Out:
# Environment : Google Colab
# TF version  : 2.19.0
# GPU         : [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# ── Storage setup (works on both Colab and Localhost) ─────────────────────
IS_COLAB = 'google.colab' in sys.modules

if IS_COLAB:
    from google.colab import drive
    drive.mount('/content/drive')
    DRIVE_DIR  = '/content/drive/MyDrive/edible_plants_models'
    DATA_ROOT  = '/content/plant_data'
else:
    # Local: save models in the project folder next to this notebook
    import pathlib
    PROJECT_DIR = str(pathlib.Path.cwd())
    DRIVE_DIR   = os.path.join(PROJECT_DIR, 'saved_models')
    DATA_ROOT   = os.path.join(PROJECT_DIR, 'plant_data')

os.makedirs(DRIVE_DIR, exist_ok=True)
os.makedirs(DATA_ROOT, exist_ok=True)

TRAIN_DIR = os.path.join(DATA_ROOT, 'train')
VAL_DIR   = os.path.join(DATA_ROOT, 'val')
TEST_DIR  = os.path.join(DATA_ROOT, 'test')

print(f"Model save dir : {DRIVE_DIR}")
print(f"Data root      : {DATA_ROOT}")
# Out:
# Mounted at /content/drive
# Model save dir : /content/drive/MyDrive/edible_plants_models
# Data root      : /content/plant_data

# %%
# !pip install kagglehub -q
import kagglehub

path = kagglehub.dataset_download("gverzea/edible-wild-plants")
print("Dataset path:", path)
# Out:
# Using Colab cache for faster access to the 'edible-wild-plants' dataset.
# Dataset path: /kaggle/input/edible-wild-plants

# %%
def find_class_root(base):
    for root, dirs, files in os.walk(base):
        if len(dirs) > 50:
            sample = os.path.join(root, dirs[0])
            if os.path.isdir(sample):
                imgs = [f for f in os.listdir(sample)
                        if f.lower().endswith(('.jpg','.jpeg','.png'))]
                if imgs: return root
    return None

SOURCE_DIR = find_class_root(path)
if SOURCE_DIR is None:
    raise RuntimeError("Cannot find class root — re-run dataset download")

GOOD_FOLDERS = [d for d in sorted(os.listdir(SOURCE_DIR))
                if os.path.isdir(os.path.join(SOURCE_DIR, d))
                and any(f.lower().endswith(('.jpg','.jpeg','.png'))
                        for f in os.listdir(os.path.join(SOURCE_DIR, d)))]
print(f"SOURCE_DIR         : {SOURCE_DIR}")
print(f"Valid class folders: {len(GOOD_FOLDERS)}")
# Out:
# SOURCE_DIR         : /kaggle/input/edible-wild-plants/datasets/dataset
# Valid class folders: 62

# %%
# Only rebuild if train folder doesn't exist or is empty
if not os.path.exists(TRAIN_DIR) or len(os.listdir(TRAIN_DIR)) == 0:
    if os.path.exists(DATA_ROOT):
        shutil.rmtree(DATA_ROOT)
    os.makedirs(DATA_ROOT)

    def make_split(source, base, classes, seed=42, train_r=0.80, val_r=0.10):
        random.seed(seed); skipped = []
        for cls in classes:
            src = os.path.join(source, cls)
            imgs = [f for f in os.listdir(src)
                    if f.lower().endswith(('.jpg','.jpeg','.png'))
                    and os.path.isfile(os.path.join(src, f))]
            if len(imgs) < 5: skipped.append(cls); continue
            random.shuffle(imgs)
            n_tr = int(len(imgs) * train_r)
            n_v  = max(int(len(imgs) * val_r), 1)
            for dest, flist in [
                (os.path.join(base,'train',cls), imgs[:n_tr]),
                (os.path.join(base,'val',  cls), imgs[n_tr:n_tr+n_v]),
                (os.path.join(base,'test', cls), imgs[n_tr+n_v:])
            ]:
                os.makedirs(dest, exist_ok=True)
                for f in flist:
                    shutil.copy2(os.path.join(src, f), os.path.join(dest, f))
        return skipped

    print("Creating 80/10/10 split …")
    skipped = make_split(SOURCE_DIR, DATA_ROOT, GOOD_FOLDERS)
    if skipped: print(f"Skipped (too few images): {skipped}")
else:
    print("Split already exists — skipping rebuild.")

for split, d in [('train',TRAIN_DIR),('val',VAL_DIR),('test',TEST_DIR)]:
    if os.path.exists(d):
        nc = len([c for c in os.listdir(d) if os.path.isdir(os.path.join(d,c))])
        ni = sum(len(os.listdir(os.path.join(d,c)))
                 for c in os.listdir(d) if os.path.isdir(os.path.join(d,c)))
        print(f"  {split}: {nc} classes, {ni} images")
# Out:
# Creating 80/10/10 split …
#   train: 62 classes, 5246 images
#   val: 62 classes, 655 images
#   test: 62 classes, 657 images

# %%
IMG_SIZE = (224, 224); BATCH_SIZE = 8; SEED = 42
tf.keras.backend.clear_session(); gc.collect()
# EfficientNet has built-in rescaling — pass raw [0,255] pixels
train_gen = ImageDataGenerator(preprocessing_function=lambda x: x,
    rotation_range=30, width_shift_range=0.15, height_shift_range=0.15,
    shear_range=0.15, zoom_range=0.2, horizontal_flip=True,
    brightness_range=[0.8,1.2], fill_mode='nearest')
vt_gen = ImageDataGenerator(preprocessing_function=lambda x: x)
train_ds = train_gen.flow_from_directory(TRAIN_DIR, target_size=IMG_SIZE,
    batch_size=BATCH_SIZE, class_mode='categorical', seed=SEED, shuffle=True)
val_ds   = vt_gen.flow_from_directory(VAL_DIR, target_size=IMG_SIZE,
    batch_size=BATCH_SIZE, class_mode='categorical', seed=SEED, shuffle=False)
test_ds  = vt_gen.flow_from_directory(TEST_DIR, target_size=IMG_SIZE,
    batch_size=BATCH_SIZE, class_mode='categorical', seed=SEED, shuffle=False)
classes = list(train_ds.class_indices.keys()); NUM_CLASSES = len(classes)
STEPS    = max(int(np.ceil(train_ds.samples / BATCH_SIZE)), 1)
VAL_STP  = max(int(np.ceil(val_ds.samples   / BATCH_SIZE)), 1)
TEST_STP = max(int(np.ceil(test_ds.samples  / BATCH_SIZE)), 1)
print(f"Classes:{NUM_CLASSES}  Train:{train_ds.samples}  Val:{val_ds.samples}  Test:{test_ds.samples}")
# Out:
# Found 5246 images belonging to 62 classes.
# Found 655 images belonging to 62 classes.
# Found 657 images belonging to 62 classes.
# Classes:62  Train:5246  Val:655  Test:657

# %%
tf.keras.backend.clear_session(); gc.collect()
base_model = tf.keras.applications.EfficientNetB0(input_shape=(*IMG_SIZE,3),
    include_top=False, weights='imagenet')
base_model.trainable = False
inp = layers.Input(shape=(*IMG_SIZE,3))
x = base_model(inp, training=False)
x = layers.GlobalAveragePooling2D()(x); x = layers.BatchNormalization()(x)
x = layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(5e-5))(x)
x = layers.Dropout(0.4)(x)
x = layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(5e-5))(x)
x = layers.Dropout(0.3)(x)
out = layers.Dense(NUM_CLASSES, activation='softmax')(x)
model = models.Model(inp, out); model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb0 (Functional)     │ (None, 7, 7, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 1280)           │         5,120 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       655,872 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 62)             │        15,934 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,857,825 (18.53 MB)
#  Trainable params: 805,694 (3.07 MB)
#  Non-trainable params: 4,052,131 (15.46 MB)

# %%
P1_CKPT    = os.path.join(DRIVE_DIR, 'EfficientNetB0_phase1_best.weights.h5')
FINAL_PATH = os.path.join(DRIVE_DIR, 'EfficientNetB0_edible_plants.keras')
model.compile(optimizer=tf.keras.optimizers.Adam(1e-3),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=['accuracy', tf.keras.metrics.AUC(name='auc'),
             tf.keras.metrics.Precision(name='precision'),
             tf.keras.metrics.Recall(name='recall')])
cb_p1 = [EarlyStopping(monitor='val_accuracy', patience=8, restore_best_weights=True, verbose=1),
         ReduceLROnPlateau(monitor='val_loss', factor=0.4, patience=3, min_lr=1e-7, verbose=1),
         ModelCheckpoint(P1_CKPT, monitor='val_accuracy',
                         save_best_only=True, save_weights_only=True, verbose=1)]
print(f"Phase 1 checkpoint -> {P1_CKPT}")
print("=== Phase 1: Head training (base FROZEN) ===")
h1 = model.fit(train_ds, epochs=30, steps_per_epoch=STEPS,
               validation_data=val_ds, validation_steps=VAL_STP,
               callbacks=cb_p1, verbose=1)
print(f"Phase 1 best val_accuracy: {max(h1.history['val_accuracy']):.4f}")
gc.collect()
# Out:
# Phase 1 checkpoint -> /content/drive/MyDrive/edible_plants_models/EfficientNetB0_phase1_best.weights.h5
# === Phase 1: Head training (base FROZEN) ===
# Epoch 1/30
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.3015 - auc: 0.8068 - loss: 3.4049 - precision: 0.7466 - recall: 0.1821
# Epoch 1: val_accuracy improved from None to 0.52519, saving model to /content/drive/MyDrive/edible_plants_models/EfficientNetB0_phase1_best.weights.h5
#
# Epoch 1: finished saving model to /content/drive/MyDrive/edible_plants_models/EfficientNetB0_phase1_best.weights.h5
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 174s 200ms/step - accuracy: 0.3673 - auc: 0.8557 - loss: 3.0925 - precision: 0.8173 - recall: 0.2286 - val_accuracy: 0.5252 - val_auc: 0.9542 - val_loss: 2.3518 - val_precision: 0.8725 - val_recall: 0.3969 - learning_rate: 0.0010
# Epoch 2/30
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.4411 - auc: 0.9161 - loss: 2.7202 - precision: 0.8054 - recall: 0.2799
# Epoch 2: val_accuracy improved from 0.52519 to 0.61527, saving model to /content/drive/MyDrive/edible_plants_models/EfficientNetB0_phase1_best.weights.h5
#
# Epoch 2: finished saving model to /content/drive/MyDrive/edible_plants_models/EfficientNetB0_phase1_best.weights.h5
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 92s 140ms/step - accuracy: 0.4575 - auc: 0.9200 - loss: 2.6896 - precision: 0.8132 - recall: 0.2838 - val_accuracy: 0.6153 - val_auc: 0.9671 - val_loss: 2.1608 - val_precision: 0.8398 - val_recall: 0.4641 - learning_rate: 0.0010
# Epoch 3/30
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.4980 - auc: 0.9369 - loss: 2.5481 - precision: 0.8298 - recall: 0.3233
# Epoch 3: val_accuracy improved from 0.61527 to 0.64275, saving model to /content/drive/MyDrive/edible_plants_models/EfficientNetB0_phase1_best.weights.h5
#
# Epoch 3: finished saving model to /content/drive/MyDrive/edible_plants_models/EfficientNetB0_phase1_best.weights.h5
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 92s 140ms/step - accuracy: 0.5048 - auc: 0.9387 - loss: 2.5282 - precision: 0.8253 - recall: 0.3233 - val_accuracy: 0.6427 - val_auc: 0.9745 - val_loss: 2.0481 - val_precision: 0.8834 - val_recall: 0.4626 - learning_rate: 0.0010
# Epoch 4/30
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.5290 - auc: 0.9455 - loss: 2.4526 - precision: 0.8320 - recall: 0.3525
# Epoch 4: val_accuracy improved from 0.64275 to 0.68702, saving model to /content/drive/MyDrive/edible_plants_models/EfficientNetB0_phase1_best.weights.h5
#
# Epoch 4: finished saving model to /content/drive/MyDrive/edible_plants_models/EfficientNetB0_phase1_best.weights.h5
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 93s 141ms/step - accuracy: 0.5301 - auc: 0.9477 - loss: 2.4392 - precision: 0.8365 - recall: 0.3521 - val_accuracy: 0.6870 - val_auc: 0.9780 - val_loss: 2.0054 - val_precision: 0.8741 - val_recall: 0.5298 - learning_rate: 0.0010
# Epoch 5/30
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.5625 - auc: 0.9582 - loss: 2.3265 - precision: 0.8546 - recall: 0.3842
# Epoch 5: val_accuracy did not improve from 0.68702
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 90s 137ms/step - accuracy: 0.5612 - auc: 0.9577 - loss: 2.3345 - precision: 0.8386 - recall: 0.3723 - val_accuracy: 0.6824 - val_auc: 0.9780 - val_loss: 1.9468 - val_precision: 0.8897 - val_recall: 0.5420 - learning_rate: 0.0010
# Epoch 6/30
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.5932 - auc: 0.9680 - loss: 2.2124 - precision: 0.8540 - recall: 0.4052
# Epoch 6: val_accuracy improved from 0.68702 to 0.70687, saving model to /content/drive/MyDrive/edible_plants_models/EfficientNetB0_phase1_best.weights.h5
#
# Epoch 6: finished saving model to /content/drive/MyDrive/edible_plants_models/EfficientNetB0_phase1_best.weights.h5
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 92s 141ms/step - accuracy: 0.5787 - auc: 0.9625 - loss: 2.2708 - precision: 0.8440 - recall: 0.3992 - val_accuracy: 0.7069 - val_auc: 0.9805 - val_loss: 1.9389 - val_precision: 0.8829 - val_recall: 0.5527 - learning_rate: 0.0010
# Epoch 7/30
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.5900 - auc: 0.9666 - loss: 2.2505 - precision: 0.8439 - recall: 0.3976
# Epoch 7: val_accuracy did not improve from 0.70687
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 91s 138ms/step - accuracy: 0.5961 - auc: 0.9652 - loss: 2.2387 - precision: 0.8443 - recall: 0.4041 - val_accuracy: 0.6931 - val_auc: 0.9815 - val_loss: 1.9290 - val_precision: 0.8690 - val_recall: 0.5573 - learning_rate: 0.0010
# Epoch 8/30
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.6265 - auc: 0.9728 - loss: 2.1543 - precision: 0.8621 - recall: 0.4411
# Epoch 8: val_accuracy improved from 0.70687 to 0.72366, saving model to /content/drive/MyDrive/edible_plants_models/EfficientNetB0_phase1_best.weights.h5
#
# Epoch 8: finished saving model to /content/drive/MyDrive/edible_plants_models/EfficientNetB0_phase1_best.weights.h5
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 91s 139ms/step - accuracy: 0.6125 - auc: 0.9704 - loss: 2.1878 - precision: 0.8594 - recall: 0.4312 - val_accuracy: 0.7237 - val_auc: 0.9837 - val_loss: 1.8739 - val_precision: 0.8801 - val_recall: 0.5603 - learning_rate: 0.0010
# Epoch 9/30
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.6326 - auc: 0.9716 - loss: 2.1542 - precision: 0.8572 - recall: 0.4487
# Epoch 9: val_accuracy did not improve from 0.72366
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 92s 140ms/step - accuracy: 0.6218 - auc: 0.9701 - loss: 2.1784 - precision: 0.8524 - recall: 0.4415 - val_accuracy: 0.7099 - val_auc: 0.9836 - val_loss: 1.8948 - val_precision: 0.8475 - val_recall: 0.6107 - learning_rate: 0.0010
# Epoch 10/30
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.6486 - auc: 0.9719 - loss: 2.1211 - precision: 0.8761 - recall: 0.4709
# Epoch 10: val_accuracy improved from 0.72366 to 0.73435, saving model to /content/drive/MyDrive/edible_plants_models/EfficientNetB0_phase1_best.weights.h5
#
# Epoch 10: finished saving model to /content/drive/MyDrive/edible_plants_models/EfficientNetB0_phase1_best.weights.h5
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 92s 140ms/step - accuracy: 0.6371 - auc: 0.9703 - loss: 2.1651 - precision: 0.8629 - recall: 0.4558 - val_accuracy: 0.7344 - val_auc: 0.9841 - val_loss: 1.9228 - val_precision: 0.8739 - val_recall: 0.6244 - learning_rate: 0.0010
# Epoch 11/30
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.6297 - auc: 0.9717 - loss: 2.1911 - precision: 0.8545 - recall: 0.4459
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0004000000189989805.
#
# Epoch 11: val_accuracy did not improve from 0.73435
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 139s 136ms/step - accuracy: 0.6374 - auc: 0.9714 - loss: 2.1783 - precision: 0.8552 - recall: 0.4537 - val_accuracy: 0.7191 - val_auc: 0.9821 - val_loss: 1.9100 - val_precision: 0.9085 - val_recall: 0.6061 - learning_rate: 0.0010
# Epoch 12/30
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.6777 - auc: 0.9780 - loss: 2.0595 - precision: 0.8963 - recall: 0.4957
# Epoch 12: val_accuracy improved from 0.73435 to 0.76183, saving model to /content/drive/MyDrive/edible_plants_models/EfficientNetB0_phase1_best.weights.h5
#
# Epoch 12: finished saving model to /content/drive/MyDrive/edible_plants_models/EfficientNetB0_phase1_best.weights.h5
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 94s 143ms/step - accuracy: 0.6851 - auc: 0.9796 - loss: 2.0255 - precision: 0.9002 - recall: 0.5019 - val_accuracy: 0.7618 - val_auc: 0.9857 - val_loss: 1.8155 - val_precision: 0.9170 - val_recall: 0.6580 - learning_rate: 4.0000e-04
# Epoch 13/30
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.7139 - auc: 0.9835 - loss: 1.9429 - precision: 0.9038 - recall: 0.5410
# Epoch 13: val_accuracy improved from 0.76183 to 0.78015, saving model to /content/drive/MyDrive/edible_plants_models/EfficientNetB0_phase1_best.weights.h5
#
# Epoch 13: finished saving model to /content/drive/MyDrive/edible_plants_models/EfficientNetB0_phase1_best.weights.h5
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 91s 139ms/step - accuracy: 0.7091 - auc: 0.9827 - loss: 1.9550 - precision: 0.9001 - recall: 0.5343 - val_accuracy: 0.7802 - val_auc: 0.9874 - val_loss: 1.7895 - val_precision: 0.9165 - val_recall: 0.6534 - learning_rate: 4.0000e-04
# Epoch 14/30
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.7201 - auc: 0.9847 - loss: 1.9209 - precision: 0.9129 - recall: 0.5461
# Epoch 14: val_accuracy did not improve from 0.78015
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 92s 140ms/step - accuracy: 0.7194 - auc: 0.9844 - loss: 1.9167 - precision: 0.9094 - recall: 0.5456 - val_accuracy: 0.7649 - val_auc: 0.9844 - val_loss: 1.8067 - val_precision: 0.8992 - val_recall: 0.6672 - learning_rate: 4.0000e-04
# Epoch 15/30
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.7203 - auc: 0.9870 - loss: 1.8794 - precision: 0.8958 - recall: 0.5464
# Epoch 15: val_accuracy improved from 0.78015 to 0.78626, saving model to /content/drive/MyDrive/edible_plants_models/EfficientNetB0_phase1_best.weights.h5
#
# Epoch 15: finished saving model to /content/drive/MyDrive/edible_plants_models/EfficientNetB0_phase1_best.weights.h5
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 92s 140ms/step - accuracy: 0.7274 - auc: 0.9867 - loss: 1.8771 - precision: 0.9030 - recall: 0.5517 - val_accuracy: 0.7863 - val_auc: 0.9823 - val_loss: 1.7590 - val_precision: 0.9193 - val_recall: 0.6779 - learning_rate: 4.0000e-04
# Epoch 16/30
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.7320 - auc: 0.9869 - loss: 1.8652 - precision: 0.9136 - recall: 0.5497
# Epoch 16: val_accuracy did not improve from 0.78626
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 93s 142ms/step - accuracy: 0.7379 - auc: 0.9872 - loss: 1.8480 - precision: 0.9114 - recall: 0.5665 - val_accuracy: 0.7756 - val_auc: 0.9864 - val_loss: 1.7452 - val_precision: 0.9119 - val_recall: 0.6794 - learning_rate: 4.0000e-04
# Epoch 17/30
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.7460 - auc: 0.9865 - loss: 1.8428 - precision: 0.9094 - recall: 0.5662
# Epoch 17: val_accuracy did not improve from 0.78626
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 89s 136ms/step - accuracy: 0.7449 - auc: 0.9877 - loss: 1.8397 - precision: 0.9107 - recall: 0.5698 - val_accuracy: 0.7817 - val_auc: 0.9863 - val_loss: 1.7503 - val_precision: 0.9046 - val_recall: 0.6656 - learning_rate: 4.0000e-04
# Epoch 18/30
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.7422 - auc: 0.9851 - loss: 1.8479 - precision: 0.9133 - recall: 0.5716
# Epoch 18: val_accuracy did not improve from 0.78626
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 89s 136ms/step - accuracy: 0.7385 - auc: 0.9857 - loss: 1.8421 - precision: 0.9177 - recall: 0.5761 - val_accuracy: 0.7817 - val_auc: 0.9855 - val_loss: 1.7437 - val_precision: 0.9074 - val_recall: 0.6733 - learning_rate: 4.0000e-04
# Epoch 19/30
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.7537 - auc: 0.9885 - loss: 1.8196 - precision: 0.9118 - recall: 0.5702
# Epoch 19: val_accuracy improved from 0.78626 to 0.79542, saving model to /content/drive/MyDrive/edible_plants_models/EfficientNetB0_phase1_best.weights.h5
#
# Epoch 19: finished saving model to /content/drive/MyDrive/edible_plants_models/EfficientNetB0_phase1_best.weights.h5
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 94s 143ms/step - accuracy: 0.7528 - auc: 0.9883 - loss: 1.8097 - precision: 0.9140 - recall: 0.5751 - val_accuracy: 0.7954 - val_auc: 0.9849 - val_loss: 1.7425 - val_precision: 0.9080 - val_recall: 0.6779 - learning_rate: 4.0000e-04
# Epoch 20/30
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.7543 - auc: 0.9881 - loss: 1.7955 - precision: 0.9008 - recall: 0.6014
# Epoch 20: val_accuracy did not improve from 0.79542
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 90s 137ms/step - accuracy: 0.7493 - auc: 0.9875 - loss: 1.8064 - precision: 0.9023 - recall: 0.5865 - val_accuracy: 0.7924 - val_auc: 0.9873 - val_loss: 1.7353 - val_precision: 0.9168 - val_recall: 0.6901 - learning_rate: 4.0000e-04
# Epoch 21/30
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.7643 - auc: 0.9905 - loss: 1.7574 - precision: 0.9233 - recall: 0.5955
# Epoch 21: val_accuracy improved from 0.79542 to 0.80153, saving model to /content/drive/MyDrive/edible_plants_models/EfficientNetB0_phase1_best.weights.h5
#
# Epoch 21: finished saving model to /content/drive/MyDrive/edible_plants_models/EfficientNetB0_phase1_best.weights.h5
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 91s 139ms/step - accuracy: 0.7621 - auc: 0.9903 - loss: 1.7564 - precision: 0.9224 - recall: 0.5986 - val_accuracy: 0.8015 - val_auc: 0.9855 - val_loss: 1.7044 - val_precision: 0.9223 - val_recall: 0.7069 - learning_rate: 4.0000e-04
# Epoch 22/30
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.7725 - auc: 0.9914 - loss: 1.7380 - precision: 0.9254 - recall: 0.6149
# Epoch 22: val_accuracy did not improve from 0.80153
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 89s 135ms/step - accuracy: 0.7688 - auc: 0.9910 - loss: 1.7486 - precision: 0.9211 - recall: 0.6100 - val_accuracy: 0.7893 - val_auc: 0.9865 - val_loss: 1.7178 - val_precision: 0.9156 - val_recall: 0.6794 - learning_rate: 4.0000e-04
# Epoch 23/30
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.7736 - auc: 0.9916 - loss: 1.7277 - precision: 0.9156 - recall: 0.6127
# Epoch 23: val_accuracy did not improve from 0.80153
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 88s 134ms/step - accuracy: 0.7741 - auc: 0.9909 - loss: 1.7319 - precision: 0.9235 - recall: 0.6140 - val_accuracy: 0.7863 - val_auc: 0.9855 - val_loss: 1.7330 - val_precision: 0.9002 - val_recall: 0.7023 - learning_rate: 4.0000e-04
# Epoch 24/30
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.7802 - auc: 0.9907 - loss: 1.7116 - precision: 0.9179 - recall: 0.6237
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.00016000000759959222.
#
# Epoch 24: val_accuracy did not improve from 0.80153
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 89s 135ms/step - accuracy: 0.7737 - auc: 0.9901 - loss: 1.7329 - precision: 0.9197 - recall: 0.6176 - val_accuracy: 0.7939 - val_auc: 0.9879 - val_loss: 1.7180 - val_precision: 0.9032 - val_recall: 0.6977 - learning_rate: 4.0000e-04
# Epoch 25/30
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.7909 - auc: 0.9917 - loss: 1.6905 - precision: 0.9296 - recall: 0.6412
# Epoch 25: val_accuracy did not improve from 0.80153
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 91s 139ms/step - accuracy: 0.7943 - auc: 0.9923 - loss: 1.6783 - precision: 0.9314 - recall: 0.6393 - val_accuracy: 0.7969 - val_auc: 0.9870 - val_loss: 1.6911 - val_precision: 0.9185 - val_recall: 0.7053 - learning_rate: 1.6000e-04
# Epoch 26/30
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.7885 - auc: 0.9926 - loss: 1.6877 - precision: 0.9330 - recall: 0.6149
# Epoch 26: val_accuracy improved from 0.80153 to 0.81374, saving model to /content/drive/MyDrive/edible_plants_models/EfficientNetB0_phase1_best.weights.h5
#
# Epoch 26: finished saving model to /content/drive/MyDrive/edible_plants_models/EfficientNetB0_phase1_best.weights.h5
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 90s 137ms/step - accuracy: 0.8002 - auc: 0.9927 - loss: 1.6622 - precision: 0.9371 - recall: 0.6418 - val_accuracy: 0.8137 - val_auc: 0.9887 - val_loss: 1.6823 - val_precision: 0.9128 - val_recall: 0.7191 - learning_rate: 1.6000e-04
# Epoch 27/30
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8044 - auc: 0.9927 - loss: 1.6477 - precision: 0.9392 - recall: 0.6589
# Epoch 27: val_accuracy did not improve from 0.81374
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 90s 137ms/step - accuracy: 0.8006 - auc: 0.9924 - loss: 1.6553 - precision: 0.9337 - recall: 0.6468 - val_accuracy: 0.8031 - val_auc: 0.9895 - val_loss: 1.6852 - val_precision: 0.9112 - val_recall: 0.7053 - learning_rate: 1.6000e-04
# Epoch 28/30
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.8033 - auc: 0.9937 - loss: 1.6422 - precision: 0.9397 - recall: 0.6429
# Epoch 28: val_accuracy did not improve from 0.81374
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 88s 135ms/step - accuracy: 0.8067 - auc: 0.9940 - loss: 1.6353 - precision: 0.9374 - recall: 0.6456 - val_accuracy: 0.8076 - val_auc: 0.9871 - val_loss: 1.6905 - val_precision: 0.9096 - val_recall: 0.7069 - learning_rate: 1.6000e-04
# Epoch 29/30
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.8116 - auc: 0.9936 - loss: 1.6282 - precision: 0.9399 - recall: 0.6683
# Epoch 29: ReduceLROnPlateau reducing learning rate to 6.40000042039901e-05.
#
# Epoch 29: val_accuracy did not improve from 0.81374
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 88s 134ms/step - accuracy: 0.8101 - auc: 0.9934 - loss: 1.6354 - precision: 0.9387 - recall: 0.6599 - val_accuracy: 0.8122 - val_auc: 0.9878 - val_loss: 1.6840 - val_precision: 0.9070 - val_recall: 0.7145 - learning_rate: 1.6000e-04
# Epoch 30/30
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.8227 - auc: 0.9939 - loss: 1.6082 - precision: 0.9429 - recall: 0.6752
# Epoch 30: val_accuracy did not improve from 0.81374
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 88s 134ms/step - accuracy: 0.8172 - auc: 0.9942 - loss: 1.6158 - precision: 0.9409 - recall: 0.6676 - val_accuracy: 0.8061 - val_auc: 0.9879 - val_loss: 1.6839 - val_precision: 0.9087 - val_recall: 0.7145 - learning_rate: 6.4000e-05
# Restoring model weights from the end of the best epoch: 26.
# Phase 1 best val_accuracy: 0.8137
# 2268

# %%
P2_CKPT = os.path.join(DRIVE_DIR, 'EfficientNetB0_phase2_best.weights.h5')
model.load_weights(P1_CKPT)
base_model.trainable = True
# Keep ALL BN layers frozen — critical for EfficientNet stability
for layer in base_model.layers:
    if isinstance(layer, layers.BatchNormalization): layer.trainable = False
for layer in base_model.layers[:-50]: layer.trainable = False
lr_schedule = tf.keras.optimizers.schedules.CosineDecay(
    initial_learning_rate=2e-5, decay_steps=max(STEPS*40,1), alpha=1e-7)
model.compile(optimizer=tf.keras.optimizers.Adam(lr_schedule),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.05),
    metrics=['accuracy', tf.keras.metrics.AUC(name='auc'),
             tf.keras.metrics.Precision(name='precision'),
             tf.keras.metrics.Recall(name='recall')])
cb_p2 = [EarlyStopping(monitor='val_accuracy', patience=12, restore_best_weights=True, verbose=1),
         ModelCheckpoint(P2_CKPT, monitor='val_accuracy',
                         save_best_only=True, save_weights_only=True, verbose=1)]
print(f"Phase 2 checkpoint -> {P2_CKPT}")
print("=== Phase 2: Fine-tuning top-50 base layers ===")
gc.collect()
h2 = model.fit(train_ds, epochs=10, steps_per_epoch=STEPS,
               validation_data=val_ds, validation_steps=VAL_STP,
               callbacks=cb_p2, verbose=1)
print(f"Phase 2 best val_accuracy: {max(h2.history['val_accuracy']):.4f}")
gc.collect()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 63 variables whereas the saved optimizer has 18 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Phase 2 checkpoint -> /content/drive/MyDrive/edible_plants_models/EfficientNetB0_phase2_best.weights.h5
# === Phase 2: Fine-tuning top-50 base layers ===
# Epoch 1/10
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.8121 - auc: 0.9948 - loss: 1.2650 - precision: 0.9377 - recall: 0.6784
# Epoch 1: val_accuracy improved from None to 0.80458, saving model to /content/drive/MyDrive/edible_plants_models/EfficientNetB0_phase2_best.weights.h5
#
# Epoch 1: finished saving model to /content/drive/MyDrive/edible_plants_models/EfficientNetB0_phase2_best.weights.h5
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 147s 182ms/step - accuracy: 0.8115 - auc: 0.9944 - loss: 1.2711 - precision: 0.9293 - recall: 0.6895 - val_accuracy: 0.8046 - val_auc: 0.9882 - val_loss: 1.3108 - val_precision: 0.8915 - val_recall: 0.7405
# Epoch 2/10
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.8393 - auc: 0.9950 - loss: 1.2003 - precision: 0.9379 - recall: 0.7244
# Epoch 2: val_accuracy improved from 0.80458 to 0.82443, saving model to /content/drive/MyDrive/edible_plants_models/EfficientNetB0_phase2_best.weights.h5
#
# Epoch 2: finished saving model to /content/drive/MyDrive/edible_plants_models/EfficientNetB0_phase2_best.weights.h5
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 92s 140ms/step - accuracy: 0.8303 - auc: 0.9940 - loss: 1.2310 - precision: 0.9303 - recall: 0.7154 - val_accuracy: 0.8244 - val_auc: 0.9869 - val_loss: 1.3128 - val_precision: 0.9007 - val_recall: 0.7481
# Epoch 3/10
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.8439 - auc: 0.9948 - loss: 1.1993 - precision: 0.9426 - recall: 0.7293
# Epoch 3: val_accuracy improved from 0.82443 to 0.82595, saving model to /content/drive/MyDrive/edible_plants_models/EfficientNetB0_phase2_best.weights.h5
#
# Epoch 3: finished saving model to /content/drive/MyDrive/edible_plants_models/EfficientNetB0_phase2_best.weights.h5
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 94s 144ms/step - accuracy: 0.8408 - auc: 0.9944 - loss: 1.2032 - precision: 0.9394 - recall: 0.7297 - val_accuracy: 0.8260 - val_auc: 0.9856 - val_loss: 1.3124 - val_precision: 0.9040 - val_recall: 0.7618
# Epoch 4/10
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.8404 - auc: 0.9944 - loss: 1.2113 - precision: 0.9314 - recall: 0.7337
# Epoch 4: val_accuracy did not improve from 0.82595
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 90s 137ms/step - accuracy: 0.8439 - auc: 0.9952 - loss: 1.1948 - precision: 0.9358 - recall: 0.7335 - val_accuracy: 0.8229 - val_auc: 0.9858 - val_loss: 1.3074 - val_precision: 0.9043 - val_recall: 0.7649
# Epoch 5/10
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8317 - auc: 0.9959 - loss: 1.1948 - precision: 0.9321 - recall: 0.7378
# Epoch 5: val_accuracy did not improve from 0.82595
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 90s 137ms/step - accuracy: 0.8422 - auc: 0.9960 - loss: 1.1797 - precision: 0.9364 - recall: 0.7461 - val_accuracy: 0.8229 - val_auc: 0.9878 - val_loss: 1.3119 - val_precision: 0.8978 - val_recall: 0.7649
# Epoch 6/10
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8420 - auc: 0.9962 - loss: 1.1738 - precision: 0.9361 - recall: 0.7387
# Epoch 6: val_accuracy did not improve from 0.82595
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 89s 135ms/step - accuracy: 0.8496 - auc: 0.9961 - loss: 1.1589 - precision: 0.9402 - recall: 0.7522 - val_accuracy: 0.8229 - val_auc: 0.9872 - val_loss: 1.2931 - val_precision: 0.9000 - val_recall: 0.7695
# Epoch 7/10
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.8545 - auc: 0.9954 - loss: 1.1663 - precision: 0.9365 - recall: 0.7543
# Epoch 7: val_accuracy did not improve from 0.82595
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 90s 137ms/step - accuracy: 0.8549 - auc: 0.9960 - loss: 1.1608 - precision: 0.9392 - recall: 0.7562 - val_accuracy: 0.8183 - val_auc: 0.9872 - val_loss: 1.3021 - val_precision: 0.8891 - val_recall: 0.7710
# Epoch 8/10
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.8560 - auc: 0.9965 - loss: 1.1601 - precision: 0.9405 - recall: 0.7478
# Epoch 8: val_accuracy did not improve from 0.82595
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 91s 139ms/step - accuracy: 0.8565 - auc: 0.9965 - loss: 1.1566 - precision: 0.9411 - recall: 0.7549 - val_accuracy: 0.8260 - val_auc: 0.9852 - val_loss: 1.3066 - val_precision: 0.8952 - val_recall: 0.7695
# Epoch 9/10
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.8609 - auc: 0.9973 - loss: 1.1188 - precision: 0.9453 - recall: 0.7705
# Epoch 9: val_accuracy did not improve from 0.82595
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 90s 137ms/step - accuracy: 0.8681 - auc: 0.9969 - loss: 1.1152 - precision: 0.9456 - recall: 0.7758 - val_accuracy: 0.8183 - val_auc: 0.9866 - val_loss: 1.2998 - val_precision: 0.8938 - val_recall: 0.7710
# Epoch 10/10
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8675 - auc: 0.9971 - loss: 1.1161 - precision: 0.9471 - recall: 0.7714
# Epoch 10: val_accuracy did not improve from 0.82595
# 656/656 ━━━━━━━━━━━━━━━━━━━━ 90s 137ms/step - accuracy: 0.8576 - auc: 0.9966 - loss: 1.1417 - precision: 0.9421 - recall: 0.7655 - val_accuracy: 0.8260 - val_auc: 0.9859 - val_loss: 1.2902 - val_precision: 0.8958 - val_recall: 0.7740
# Restoring model weights from the end of the best epoch: 3.
# Phase 2 best val_accuracy: 0.8260
# 1843

# %%
def combine(h1, h2, key): return h1.history.get(key,[]) + h2.history.get(key,[])
phase1_end = len(h1.history['accuracy'])
pairs = [('accuracy','val_accuracy','Accuracy'),('loss','val_loss','Loss'),
         ('auc','val_auc','AUC'),('precision','val_precision','Precision'),('recall','val_recall','Recall')]
fig, axes = plt.subplots(2, 3, figsize=(20,12))
for ax,(tr,vl,title) in zip(axes.flat, pairs):
    ax.plot(combine(h1,h2,tr), color='steelblue', lw=2, label='Train')
    ax.plot(combine(h1,h2,vl), color='coral',     lw=2, label='Val')
    ax.axvline(phase1_end, color='gray', linestyle='--', alpha=0.7, label='Fine-tune start')
    ax.set_title(f'EfficientNetB0 — {title}', fontweight='bold'); ax.legend(); ax.grid(alpha=0.3)
ax_s = axes.flat[-1]; ax_s.axis('off')
ax_s.text(0.05,0.5, f"EfficientNetB0 Summary\nP1: {max(h1.history['val_accuracy']):.4f}\nP2: {max(h2.history['val_accuracy']):.4f}\nBest: {max(combine(h1,h2,'val_accuracy')):.4f}",
    fontsize=12,family='monospace',verticalalignment='center',
    bbox=dict(boxstyle='round',facecolor='lightyellow',alpha=0.5))
plt.tight_layout(); plt.show()

# %%
print("Running streaming predictions on test set …")
y_pred_list = []; y_true_list = []
test_ds.reset()
for batch_x, batch_y in test_ds:
    preds = model.predict_on_batch(batch_x)
    y_pred_list.append(np.argmax(preds,   axis=1))
    y_true_list.append(np.argmax(batch_y, axis=1))
    if len(y_pred_list) >= TEST_STP: break
y_pred = np.concatenate(y_pred_list)
y_true = np.concatenate(y_true_list)
del y_pred_list, y_true_list; gc.collect()
n = min(len(y_pred), len(y_true)); y_pred, y_true = y_pred[:n], y_true[:n]

acc  = accuracy_score (y_true, y_pred)
prec = precision_score(y_true, y_pred, average='weighted', zero_division=0)
rec  = recall_score   (y_true, y_pred, average='weighted', zero_division=0)
f1   = f1_score       (y_true, y_pred, average='weighted', zero_division=0)
print(f"\n  Accuracy  : {acc:.4f}")
print(f"  Precision : {prec:.4f}")
print(f"  Recall    : {rec:.4f}")
print(f"  F1-Score  : {f1:.4f}")
print(f"  Grade     : {'EXCELLENT (>=90%)' if acc>=0.90 else 'GOOD (>=80%)' if acc>=0.80 else 'Needs tuning'}")
print("\n—— Classification Report ——")
print(classification_report(y_true, y_pred, labels=np.arange(len(classes)),
                             target_names=classes, zero_division=0))
# Out:
# Running streaming predictions on test set …
#
#   Accuracy  : 0.7945
#   Precision : 0.8084
#   Recall    : 0.7945
#   F1-Score  : 0.7909
#   Grade     : Needs tuning
#
# —— Classification Report ——
#                      precision    recall  f1-score   support
#
#             Alfalfa       0.67      0.40      0.50         5
#           Asparagus       0.89      0.80      0.84        10
#        Blue Vervain       1.00      1.00      1.00         5
#  Broadleaf Plantain       0.43      0.60      0.50         5
#        Bull Thistle       0.60      0.60      0.60         5
#             Cattail       0.50      1.00      0.67         5
#           Chickweed       0.73      0.73      0.73        15
#             Chicory       1.00      1.00      1.00         5
#            Cleavers       0.56      1.00      0.71         5
#           Coltsfoot       0.67      0.80      0.73         5
#  Common Sow Thistle       1.00      0.80      0.89        10
#       Common Yarrow       0.33      0.20      0.25         5
#          Coneflower       0.62      1.00      0.77         5
#    Creeping Charlie       0.62      0.50      0.56        10
#      Crimson Clover       0.83      1.00      0.91         5
#          Curly Dock       0.69      0.60      0.64        15
#      Daisy Fleabane       0.94      0.95      0.94        77
#          Dandellion       0.92      0.92      0.92       106
# Downy Yellow Violet       0.71      1.00      0.83         5
#          Elderberry       0.78      0.70      0.74        10
#    Evening Primrose       0.80      0.80      0.80         5
#    Fern Leaf Yarrow       0.67      0.80      0.73         5
#    Field Pennycress       0.64      0.70      0.67        10
#            Fireweed       0.71      1.00      0.83         5
#       Forget Me Not       1.00      0.80      0.89         5
#      Garlic Mustard       0.75      0.90      0.82        10
#            Harebell       0.71      1.00      0.83         5
#              Henbit       0.71      0.67      0.69        15
#         Herb Robert       1.00      0.60      0.75         5
#   Japanese Knotweed       1.00      0.20      0.33         5
#        Joe Pye Weed       1.00      0.40      0.57         5
#            Knapweed       0.67      0.80      0.73         5
#               Kudzu       0.75      0.60      0.67         5
#      Lambs Quarters       0.50      0.67      0.57        15
#              Mallow       1.00      0.60      0.75         5
#            Mayapple       1.00      0.60      0.75         5
#         Meadowsweet       0.50      0.40      0.44         5
#        Milk Thistle       0.67      0.80      0.73         5
#             Mullein       0.60      0.60      0.60         5
#   New England Aster       0.80      0.80      0.80         5
#      Partridgeberry       0.67      0.80      0.73         5
#         Peppergrass       0.82      0.60      0.69        15
#        Pickerelweed       0.80      0.80      0.80         5
#      Pineapple Weed       0.75      0.60      0.67         5
# Prickly Pear Cactus       0.67      0.40      0.50         5
#   Purple Deadnettle       0.57      0.40      0.47        10
#    Queen Annes Lace       0.83      1.00      0.91         5
#          Red Clover       0.80      0.80      0.80         5
#        Sheep Sorrel       0.50      0.80      0.62         5
#     Shepherds Purse       0.78      0.70      0.74        10
#       Spring Beauty       0.80      0.80      0.80         5
#           Sunflower       0.96      0.92      0.94        74
#     Supplejack Vine       0.33      0.20      0.25         5
#           Tea Plant       0.43      0.60      0.50         5
#              Teasel       1.00      0.80      0.89         5
#           Toothwort       0.64      0.70      0.67        10
#      Vervain Mallow       1.00      0.60      0.75         5
#       Wild Bee Balm       0.75      0.60      0.67         5
#   Wild Black Cherry       0.67      0.80      0.73         5
#     Wild Grape Vine       0.69      0.90      0.78        10
#           Wild Leek       0.82      0.90      0.86        10
#         Wood Sorrel       0.71      1.00      0.83         5
#
#            accuracy                           0.79       657
#           macro avg       0.74      0.73      0.71       657
#        weighted avg       0.81      0.79      0.79       657

# %%
cm  = confusion_matrix(y_true, y_pred, labels=np.arange(len(classes)))
fsz = max(10, len(classes)//2)
plt.figure(figsize=(fsz, fsz-2))
sns.heatmap(cm, annot=(len(classes)<=20), fmt='d',
            xticklabels=classes, yticklabels=classes, cmap='Oranges')
plt.title('EfficientNetB0 — Confusion Matrix', fontsize=14)
plt.ylabel('True Label'); plt.xlabel('Predicted Label')
plt.xticks(rotation=90, fontsize=7); plt.yticks(rotation=0, fontsize=7)
plt.tight_layout(); plt.show()
del y_pred, y_true; gc.collect()
# Out:
# 16524

# %%
model.save(FINAL_PATH)
print(f"Model saved: {FINAL_PATH}")
gc.collect(); tf.keras.backend.clear_session()
# Out:
# Model saved: /content/drive/MyDrive/edible_plants_models/EfficientNetB0_edible_plants.keras

# %%
# ── Upload ALL saved files to Google Drive ────────────────────────────────
# Uploads: phase1 checkpoint, phase2 checkpoint, final .keras model
# Works from LOCAL machine only. Skipped automatically on Colab.
IS_COLAB = 'google.colab' in sys.modules

if IS_COLAB:
    print("Running on Colab — all files already saved to Drive. Nothing to upload.")
else:
    print("Running locally — uploading all files from saved_models/ to Google Drive …")
    try:
        import subprocess as _sp, sys as _sys
        _sp.check_call([_sys.executable, '-m', 'pip', 'install', 'pydrive2', '-q'])

        from pydrive2.auth import GoogleAuth
        from pydrive2.drive import GoogleDrive

        # One-time browser login (cached after first run)
        gauth = GoogleAuth()
        gauth.LocalWebserverAuth()
        gdrive = GoogleDrive(gauth)

        # Find or create 'edible_plants_models' folder in Drive root
        folder_list = gdrive.ListFile(
            {'q': "title='edible_plants_models' and "
                  "mimeType='application/vnd.google-apps.folder' and "
                  "trashed=false"}
        ).GetList()

        if folder_list:
            folder_id = folder_list[0]['id']
            print(f"Found Drive folder  : edible_plants_models (id={folder_id})")
        else:
            folder = gdrive.CreateFile({
                'title': 'edible_plants_models',
                'mimeType': 'application/vnd.google-apps.folder'
            })
            folder.Upload()
            folder_id = folder['id']
            print(f"Created Drive folder: edible_plants_models (id={folder_id})")

        # Upload every file inside DRIVE_DIR (saved_models/)
        all_files = [f for f in os.listdir(DRIVE_DIR)
                     if os.path.isfile(os.path.join(DRIVE_DIR, f))]

        if not all_files:
            print("No files found in saved_models/ — make sure training completed.")
        else:
            print(f"\nUploading {len(all_files)} file(s):")
            for fname in sorted(all_files):
                local_path = os.path.join(DRIVE_DIR, fname)
                size_mb = os.path.getsize(local_path) / (1024 * 1024)

                # Check if file already exists in Drive folder → update it
                existing = gdrive.ListFile(
                    {'q': f"title='{fname}' and '{folder_id}' in parents and trashed=false"}
                ).GetList()

                if existing:
                    gfile = existing[0]
                    gfile.SetContentFile(local_path)
                    gfile.Upload()
                    print(f"  Updated  {fname:50s}  ({size_mb:.1f} MB)")
                else:
                    gfile = gdrive.CreateFile({
                        'title': fname,
                        'parents': [{'id': folder_id}]
                    })
                    gfile.SetContentFile(local_path)
                    gfile.Upload()
                    print(f"  Uploaded {fname:50s}  ({size_mb:.1f} MB)")

            print("\nAll files uploaded to Drive/edible_plants_models/")
            print("Open modelcomparison.ipynb on Colab to compare all models.")

    except Exception as e:
        print(f"Auto-upload failed: {e}")
        print("\nManual option:")
        print(f"  Go to drive.google.com → My Drive")
        print(f"  Create folder 'edible_plants_models' if it doesn't exist")
        print(f"  Upload all files from: {DRIVE_DIR}")
# Out:
# Running on Colab — all files already saved to Drive. Nothing to upload.
