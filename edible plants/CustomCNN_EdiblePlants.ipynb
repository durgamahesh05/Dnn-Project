# %% [markdown]
# # Custom CNN — Edible Plants (62 Classes)
# > Works on **Google Colab** and **Local Jupyter**
# > Models saved permanently — auto-uploaded to Drive from local

# %%
import sys, os, gc, random, shutil
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import (EarlyStopping, ReduceLROnPlateau,
                                         ModelCheckpoint)
from sklearn.metrics import (classification_report, confusion_matrix,
                              accuracy_score, precision_score,
                              recall_score, f1_score)
import seaborn as sns

SEED = 42
random.seed(SEED); np.random.seed(SEED); tf.random.set_seed(SEED)

# ── Environment detection ─────────────────────────────────────────────────
IS_COLAB = 'google.colab' in sys.modules
print(f"Environment : {'Google Colab' if IS_COLAB else 'Local (Jupyter)'}")
print(f"TF version  : {tf.__version__}")
print(f"GPU         : {tf.config.list_physical_devices('GPU')}")
# Out:
# Environment : Google Colab
# TF version  : 2.19.0
# GPU         : [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# ── Storage setup (works on both Colab and Localhost) ─────────────────────
IS_COLAB = 'google.colab' in sys.modules

if IS_COLAB:
    from google.colab import drive
    drive.mount('/content/drive')
    DRIVE_DIR  = '/content/drive/MyDrive/edible_plants_models'
    DATA_ROOT  = '/content/plant_data'
else:
    # Local: save models in the project folder next to this notebook
    import pathlib
    PROJECT_DIR = str(pathlib.Path.cwd())
    DRIVE_DIR   = os.path.join(PROJECT_DIR, 'saved_models')
    DATA_ROOT   = os.path.join(PROJECT_DIR, 'plant_data')

os.makedirs(DRIVE_DIR, exist_ok=True)
os.makedirs(DATA_ROOT, exist_ok=True)

TRAIN_DIR = os.path.join(DATA_ROOT, 'train')
VAL_DIR   = os.path.join(DATA_ROOT, 'val')
TEST_DIR  = os.path.join(DATA_ROOT, 'test')

print(f"Model save dir : {DRIVE_DIR}")
print(f"Data root      : {DATA_ROOT}")
# Out:
# Mounted at /content/drive
# Model save dir : /content/drive/MyDrive/edible_plants_models
# Data root      : /content/plant_data

# %%
# !pip install kagglehub -q
import kagglehub

path = kagglehub.dataset_download("gverzea/edible-wild-plants")
print("Dataset path:", path)
# Out:
# Downloading to /root/.cache/kagglehub/datasets/gverzea/edible-wild-plants/5.archive...
# 100%|██████████| 766M/766M [00:18<00:00, 44.1MB/s]
# Extracting files...
# Dataset path: /root/.cache/kagglehub/datasets/gverzea/edible-wild-plants/versions/5

# %%
def find_class_root(base):
    for root, dirs, files in os.walk(base):
        if len(dirs) > 50:
            sample = os.path.join(root, dirs[0])
            if os.path.isdir(sample):
                imgs = [f for f in os.listdir(sample)
                        if f.lower().endswith(('.jpg','.jpeg','.png'))]
                if imgs: return root
    return None

SOURCE_DIR = find_class_root(path)
if SOURCE_DIR is None:
    raise RuntimeError("Cannot find class root — re-run dataset download")

GOOD_FOLDERS = [d for d in sorted(os.listdir(SOURCE_DIR))
                if os.path.isdir(os.path.join(SOURCE_DIR, d))
                and any(f.lower().endswith(('.jpg','.jpeg','.png'))
                        for f in os.listdir(os.path.join(SOURCE_DIR, d)))]
print(f"SOURCE_DIR         : {SOURCE_DIR}")
print(f"Valid class folders: {len(GOOD_FOLDERS)}")
# Out:
# SOURCE_DIR         : /root/.cache/kagglehub/datasets/gverzea/edible-wild-plants/versions/5/datasets/dataset
# Valid class folders: 62

# %%
# Only rebuild if train folder doesn't exist or is empty
if not os.path.exists(TRAIN_DIR) or len(os.listdir(TRAIN_DIR)) == 0:
    if os.path.exists(DATA_ROOT):
        shutil.rmtree(DATA_ROOT)
    os.makedirs(DATA_ROOT)

    def make_split(source, base, classes, seed=42, train_r=0.80, val_r=0.10):
        random.seed(seed); skipped = []
        for cls in classes:
            src = os.path.join(source, cls)
            imgs = [f for f in os.listdir(src)
                    if f.lower().endswith(('.jpg','.jpeg','.png'))
                    and os.path.isfile(os.path.join(src, f))]
            if len(imgs) < 5: skipped.append(cls); continue
            random.shuffle(imgs)
            n_tr = int(len(imgs) * train_r)
            n_v  = max(int(len(imgs) * val_r), 1)
            for dest, flist in [
                (os.path.join(base,'train',cls), imgs[:n_tr]),
                (os.path.join(base,'val',  cls), imgs[n_tr:n_tr+n_v]),
                (os.path.join(base,'test', cls), imgs[n_tr+n_v:])
            ]:
                os.makedirs(dest, exist_ok=True)
                for f in flist:
                    shutil.copy2(os.path.join(src, f), os.path.join(dest, f))
        return skipped

    print("Creating 80/10/10 split …")
    skipped = make_split(SOURCE_DIR, DATA_ROOT, GOOD_FOLDERS)
    if skipped: print(f"Skipped (too few images): {skipped}")
else:
    print("Split already exists — skipping rebuild.")

for split, d in [('train',TRAIN_DIR),('val',VAL_DIR),('test',TEST_DIR)]:
    if os.path.exists(d):
        nc = len([c for c in os.listdir(d) if os.path.isdir(os.path.join(d,c))])
        ni = sum(len(os.listdir(os.path.join(d,c)))
                 for c in os.listdir(d) if os.path.isdir(os.path.join(d,c)))
        print(f"  {split}: {nc} classes, {ni} images")
# Out:
# Creating 80/10/10 split …
#   train: 62 classes, 5246 images
#   val: 62 classes, 655 images
#   test: 62 classes, 657 images

# %%
IMG_SIZE = (128, 128); BATCH_SIZE = 16; SEED = 42
tf.keras.backend.clear_session(); gc.collect()

train_gen = ImageDataGenerator(
    rescale=1./255, rotation_range=25, width_shift_range=0.15,
    height_shift_range=0.15, shear_range=0.15, zoom_range=0.2,
    horizontal_flip=True, brightness_range=[0.8,1.2], fill_mode='nearest')
vt_gen = ImageDataGenerator(rescale=1./255)

train_ds = train_gen.flow_from_directory(TRAIN_DIR, target_size=IMG_SIZE,
    batch_size=BATCH_SIZE, class_mode='categorical', seed=SEED, shuffle=True)
val_ds   = vt_gen.flow_from_directory(VAL_DIR, target_size=IMG_SIZE,
    batch_size=BATCH_SIZE, class_mode='categorical', seed=SEED, shuffle=False)
test_ds  = vt_gen.flow_from_directory(TEST_DIR, target_size=IMG_SIZE,
    batch_size=BATCH_SIZE, class_mode='categorical', seed=SEED, shuffle=False)

classes = list(train_ds.class_indices.keys()); NUM_CLASSES = len(classes)
STEPS    = max(int(np.ceil(train_ds.samples / BATCH_SIZE)), 1)
VAL_STP  = max(int(np.ceil(val_ds.samples   / BATCH_SIZE)), 1)
TEST_STP = max(int(np.ceil(test_ds.samples  / BATCH_SIZE)), 1)
print(f"Classes:{NUM_CLASSES}  Train:{train_ds.samples}  Val:{val_ds.samples}  Test:{test_ds.samples}")
# Out:
# Found 5246 images belonging to 62 classes.
# Found 655 images belonging to 62 classes.
# Found 657 images belonging to 62 classes.
# Classes:62  Train:5246  Val:655  Test:657

# %%
tf.keras.backend.clear_session(); gc.collect()
def conv_block(x, filters, pool=True):
    x = layers.Conv2D(filters, 3, padding='same', kernel_regularizer=regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    if pool: x = layers.MaxPooling2D()(x); x = layers.SpatialDropout2D(0.1)(x)
    return x
inp = layers.Input(shape=(*IMG_SIZE, 3))
x = conv_block(inp, 32); x = conv_block(x, 64); x = conv_block(x, 128)
x = conv_block(x, 256);  x = conv_block(x, 512, pool=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(1e-4))(x)
x = layers.BatchNormalization()(x); x = layers.Dropout(0.5)(x)
x = layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(1e-4))(x)
x = layers.Dropout(0.4)(x)
out = layers.Dense(NUM_CLASSES, activation='softmax')(x)
model = models.Model(inp, out)
model.summary(); print(f"Total params: {model.count_params():,}")
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 128, 128, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128, 128, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 128, 128, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ spatial_dropout2d               │ (None, 64, 64, 32)     │             0 │
# │ (SpatialDropout2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64, 64, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ spatial_dropout2d_1             │ (None, 32, 32, 64)     │             0 │
# │ (SpatialDropout2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 32, 32, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ spatial_dropout2d_2             │ (None, 16, 16, 128)    │             0 │
# │ (SpatialDropout2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16, 16, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 16, 16, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ spatial_dropout2d_3             │ (None, 8, 8, 256)      │             0 │
# │ (SpatialDropout2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 8, 8, 512)      │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 8, 8, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 8, 8, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 62)             │        15,934 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,984,510 (7.57 MB)
#  Trainable params: 1,981,502 (7.56 MB)
#  Non-trainable params: 3,008 (11.75 KB)
# Total params: 1,984,510

# %%
CKPT_PATH  = os.path.join(DRIVE_DIR, 'CustomCNN_best.weights.h5')
FINAL_PATH = os.path.join(DRIVE_DIR, 'CustomCNN_edible_plants.keras')

model.compile(optimizer=tf.keras.optimizers.Adam(1e-3),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=['accuracy', tf.keras.metrics.AUC(name='auc'),
             tf.keras.metrics.Precision(name='precision'),
             tf.keras.metrics.Recall(name='recall')])

callbacks = [
    EarlyStopping(monitor='val_accuracy', patience=10, restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.4, patience=4, min_lr=1e-7, verbose=1),
    ModelCheckpoint(CKPT_PATH, monitor='val_accuracy',
                    save_best_only=True, save_weights_only=True, verbose=1)]

print(f"Checkpoint -> {CKPT_PATH}")
print("=== Training Custom CNN ===")
history = model.fit(train_ds, epochs=60, steps_per_epoch=STEPS,
                    validation_data=val_ds, validation_steps=VAL_STP,
                    callbacks=callbacks, verbose=1)
print(f"Best val_accuracy: {max(history.history['val_accuracy']):.4f}")
gc.collect()
# Out:
# Checkpoint -> /content/drive/MyDrive/edible_plants_models/CustomCNN_best.weights.h5
# === Training Custom CNN ===
# Epoch 1/60
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.1340 - auc: 0.6550 - loss: 4.5832 - precision: 0.2622 - recall: 0.0378
# Epoch 1: val_accuracy improved from None to 0.17710, saving model to /content/drive/MyDrive/edible_plants_models/CustomCNN_best.weights.h5
#
# Epoch 1: finished saving model to /content/drive/MyDrive/edible_plants_models/CustomCNN_best.weights.h5
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 86s 181ms/step - accuracy: 0.1655 - auc: 0.7036 - loss: 4.2200 - precision: 0.3256 - recall: 0.0456 - val_accuracy: 0.1771 - val_auc: 0.7815 - val_loss: 3.6427 - val_precision: 0.2500 - val_recall: 0.0061 - learning_rate: 0.0010
# Epoch 2/60
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.2162 - auc: 0.7635 - loss: 3.7369 - precision: 0.4695 - recall: 0.0568
# Epoch 2: val_accuracy improved from 0.17710 to 0.25649, saving model to /content/drive/MyDrive/edible_plants_models/CustomCNN_best.weights.h5
#
# Epoch 2: finished saving model to /content/drive/MyDrive/edible_plants_models/CustomCNN_best.weights.h5
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 50s 145ms/step - accuracy: 0.2261 - auc: 0.7764 - loss: 3.6680 - precision: 0.5088 - recall: 0.0661 - val_accuracy: 0.2565 - val_auc: 0.8334 - val_loss: 3.4569 - val_precision: 0.8065 - val_recall: 0.0382 - learning_rate: 0.0010
# Epoch 3/60
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.2241 - auc: 0.8101 - loss: 3.5596 - precision: 0.5448 - recall: 0.0633
# Epoch 3: val_accuracy improved from 0.25649 to 0.27176, saving model to /content/drive/MyDrive/edible_plants_models/CustomCNN_best.weights.h5
#
# Epoch 3: finished saving model to /content/drive/MyDrive/edible_plants_models/CustomCNN_best.weights.h5
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 47s 142ms/step - accuracy: 0.2343 - auc: 0.8152 - loss: 3.5199 - precision: 0.5540 - recall: 0.0694 - val_accuracy: 0.2718 - val_auc: 0.8671 - val_loss: 3.2990 - val_precision: 0.7024 - val_recall: 0.0901 - learning_rate: 0.0010
# Epoch 4/60
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.2710 - auc: 0.8343 - loss: 3.4403 - precision: 0.5893 - recall: 0.0749
# Epoch 4: val_accuracy did not improve from 0.27176
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 45s 138ms/step - accuracy: 0.2699 - auc: 0.8328 - loss: 3.4371 - precision: 0.5980 - recall: 0.0814 - val_accuracy: 0.2137 - val_auc: 0.8203 - val_loss: 3.6066 - val_precision: 0.4779 - val_recall: 0.0992 - learning_rate: 0.0010
# Epoch 5/60
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.2828 - auc: 0.8466 - loss: 3.3607 - precision: 0.6536 - recall: 0.0981
# Epoch 5: val_accuracy improved from 0.27176 to 0.29160, saving model to /content/drive/MyDrive/edible_plants_models/CustomCNN_best.weights.h5
#
# Epoch 5: finished saving model to /content/drive/MyDrive/edible_plants_models/CustomCNN_best.weights.h5
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 46s 140ms/step - accuracy: 0.2836 - auc: 0.8478 - loss: 3.3609 - precision: 0.6514 - recall: 0.1005 - val_accuracy: 0.2916 - val_auc: 0.8640 - val_loss: 3.2818 - val_precision: 0.6182 - val_recall: 0.1038 - learning_rate: 0.0010
# Epoch 6/60
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.2841 - auc: 0.8589 - loss: 3.3149 - precision: 0.6277 - recall: 0.0983
# Epoch 6: val_accuracy did not improve from 0.29160
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 81s 137ms/step - accuracy: 0.2901 - auc: 0.8602 - loss: 3.2939 - precision: 0.6616 - recall: 0.1088 - val_accuracy: 0.2779 - val_auc: 0.8719 - val_loss: 3.2516 - val_precision: 0.7193 - val_recall: 0.1252 - learning_rate: 0.0010
# Epoch 7/60
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.3132 - auc: 0.8699 - loss: 3.2267 - precision: 0.7060 - recall: 0.1308
# Epoch 7: val_accuracy improved from 0.29160 to 0.30534, saving model to /content/drive/MyDrive/edible_plants_models/CustomCNN_best.weights.h5
#
# Epoch 7: finished saving model to /content/drive/MyDrive/edible_plants_models/CustomCNN_best.weights.h5
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 47s 142ms/step - accuracy: 0.2962 - auc: 0.8674 - loss: 3.2527 - precision: 0.6923 - recall: 0.1218 - val_accuracy: 0.3053 - val_auc: 0.8918 - val_loss: 3.1333 - val_precision: 0.7468 - val_recall: 0.1756 - learning_rate: 0.0010
# Epoch 8/60
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.3004 - auc: 0.8751 - loss: 3.2347 - precision: 0.6774 - recall: 0.1150
# Epoch 8: val_accuracy did not improve from 0.30534
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 47s 145ms/step - accuracy: 0.3033 - auc: 0.8716 - loss: 3.2392 - precision: 0.6869 - recall: 0.1184 - val_accuracy: 0.3053 - val_auc: 0.9131 - val_loss: 2.9802 - val_precision: 0.6493 - val_recall: 0.1328 - learning_rate: 0.0010
# Epoch 9/60
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.2964 - auc: 0.8719 - loss: 3.2307 - precision: 0.6672 - recall: 0.1207
# Epoch 9: val_accuracy improved from 0.30534 to 0.31603, saving model to /content/drive/MyDrive/edible_plants_models/CustomCNN_best.weights.h5
#
# Epoch 9: finished saving model to /content/drive/MyDrive/edible_plants_models/CustomCNN_best.weights.h5
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 46s 142ms/step - accuracy: 0.3037 - auc: 0.8744 - loss: 3.2125 - precision: 0.6823 - recall: 0.1273 - val_accuracy: 0.3160 - val_auc: 0.9018 - val_loss: 3.0697 - val_precision: 0.7397 - val_recall: 0.1649 - learning_rate: 0.0010
# Epoch 10/60
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.3224 - auc: 0.8879 - loss: 3.1429 - precision: 0.7039 - recall: 0.1292
# Epoch 10: val_accuracy did not improve from 0.31603
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 45s 138ms/step - accuracy: 0.3159 - auc: 0.8826 - loss: 3.1686 - precision: 0.7043 - recall: 0.1308 - val_accuracy: 0.3115 - val_auc: 0.9058 - val_loss: 3.0525 - val_precision: 0.6993 - val_recall: 0.1527 - learning_rate: 0.0010
# Epoch 11/60
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.3115 - auc: 0.8873 - loss: 3.1323 - precision: 0.7155 - recall: 0.1386
# Epoch 11: val_accuracy improved from 0.31603 to 0.34046, saving model to /content/drive/MyDrive/edible_plants_models/CustomCNN_best.weights.h5
#
# Epoch 11: finished saving model to /content/drive/MyDrive/edible_plants_models/CustomCNN_best.weights.h5
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 46s 141ms/step - accuracy: 0.3147 - auc: 0.8868 - loss: 3.1424 - precision: 0.7191 - recall: 0.1430 - val_accuracy: 0.3405 - val_auc: 0.9220 - val_loss: 2.9319 - val_precision: 0.8411 - val_recall: 0.1374 - learning_rate: 0.0010
# Epoch 12/60
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.3177 - auc: 0.8937 - loss: 3.1062 - precision: 0.7109 - recall: 0.1352
# Epoch 12: val_accuracy did not improve from 0.34046
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 46s 139ms/step - accuracy: 0.3185 - auc: 0.8898 - loss: 3.1251 - precision: 0.7163 - recall: 0.1348 - val_accuracy: 0.3237 - val_auc: 0.8995 - val_loss: 3.0456 - val_precision: 0.7362 - val_recall: 0.1832 - learning_rate: 0.0010
# Epoch 13/60
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.3294 - auc: 0.8952 - loss: 3.0815 - precision: 0.7379 - recall: 0.1578
# Epoch 13: val_accuracy did not improve from 0.34046
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 45s 136ms/step - accuracy: 0.3326 - auc: 0.8948 - loss: 3.0880 - precision: 0.7353 - recall: 0.1504 - val_accuracy: 0.3298 - val_auc: 0.9017 - val_loss: 3.0711 - val_precision: 0.7279 - val_recall: 0.1511 - learning_rate: 0.0010
# Epoch 14/60
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.3257 - auc: 0.8970 - loss: 3.0739 - precision: 0.7422 - recall: 0.1598
# Epoch 14: val_accuracy improved from 0.34046 to 0.35573, saving model to /content/drive/MyDrive/edible_plants_models/CustomCNN_best.weights.h5
#
# Epoch 14: finished saving model to /content/drive/MyDrive/edible_plants_models/CustomCNN_best.weights.h5
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 46s 140ms/step - accuracy: 0.3248 - auc: 0.8940 - loss: 3.0927 - precision: 0.7433 - recall: 0.1529 - val_accuracy: 0.3557 - val_auc: 0.9091 - val_loss: 2.9825 - val_precision: 0.7405 - val_recall: 0.1786 - learning_rate: 0.0010
# Epoch 15/60
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.3301 - auc: 0.8963 - loss: 3.0794 - precision: 0.7365 - recall: 0.1475
# Epoch 15: val_accuracy improved from 0.35573 to 0.36183, saving model to /content/drive/MyDrive/edible_plants_models/CustomCNN_best.weights.h5
#
# Epoch 15: finished saving model to /content/drive/MyDrive/edible_plants_models/CustomCNN_best.weights.h5
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 47s 144ms/step - accuracy: 0.3319 - auc: 0.8947 - loss: 3.0821 - precision: 0.7298 - recall: 0.1529 - val_accuracy: 0.3618 - val_auc: 0.9256 - val_loss: 2.9041 - val_precision: 0.7771 - val_recall: 0.1863 - learning_rate: 0.0010
# Epoch 16/60
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.3383 - auc: 0.8999 - loss: 3.0568 - precision: 0.7347 - recall: 0.1620
# Epoch 16: val_accuracy did not improve from 0.36183
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 45s 138ms/step - accuracy: 0.3332 - auc: 0.8982 - loss: 3.0676 - precision: 0.7302 - recall: 0.1563 - val_accuracy: 0.3450 - val_auc: 0.9129 - val_loss: 2.9901 - val_precision: 0.6886 - val_recall: 0.1756 - learning_rate: 0.0010
# Epoch 17/60
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.3357 - auc: 0.9005 - loss: 3.0403 - precision: 0.7260 - recall: 0.1613
# Epoch 17: val_accuracy improved from 0.36183 to 0.37252, saving model to /content/drive/MyDrive/edible_plants_models/CustomCNN_best.weights.h5
#
# Epoch 17: finished saving model to /content/drive/MyDrive/edible_plants_models/CustomCNN_best.weights.h5
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 47s 142ms/step - accuracy: 0.3366 - auc: 0.9002 - loss: 3.0453 - precision: 0.7305 - recall: 0.1592 - val_accuracy: 0.3725 - val_auc: 0.9234 - val_loss: 2.9064 - val_precision: 0.8608 - val_recall: 0.1038 - learning_rate: 0.0010
# Epoch 18/60
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.3508 - auc: 0.9014 - loss: 3.0400 - precision: 0.7760 - recall: 0.1678
# Epoch 18: val_accuracy improved from 0.37252 to 0.38626, saving model to /content/drive/MyDrive/edible_plants_models/CustomCNN_best.weights.h5
#
# Epoch 18: finished saving model to /content/drive/MyDrive/edible_plants_models/CustomCNN_best.weights.h5
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 48s 147ms/step - accuracy: 0.3422 - auc: 0.9020 - loss: 3.0353 - precision: 0.7688 - recall: 0.1641 - val_accuracy: 0.3863 - val_auc: 0.9300 - val_loss: 2.8550 - val_precision: 0.8000 - val_recall: 0.1710 - learning_rate: 0.0010
# Epoch 19/60
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.3357 - auc: 0.9059 - loss: 3.0204 - precision: 0.7367 - recall: 0.1609
# Epoch 19: val_accuracy did not improve from 0.38626
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 79s 139ms/step - accuracy: 0.3324 - auc: 0.9018 - loss: 3.0501 - precision: 0.7396 - recall: 0.1565 - val_accuracy: 0.3710 - val_auc: 0.9326 - val_loss: 2.8357 - val_precision: 0.7815 - val_recall: 0.1802 - learning_rate: 0.0010
# Epoch 20/60
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.3496 - auc: 0.9077 - loss: 3.0132 - precision: 0.7523 - recall: 0.1627
# Epoch 20: val_accuracy did not improve from 0.38626
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 46s 140ms/step - accuracy: 0.3517 - auc: 0.9064 - loss: 3.0126 - precision: 0.7519 - recall: 0.1664 - val_accuracy: 0.3527 - val_auc: 0.9069 - val_loss: 2.9765 - val_precision: 0.7643 - val_recall: 0.1832 - learning_rate: 0.0010
# Epoch 21/60
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.3316 - auc: 0.9072 - loss: 3.0221 - precision: 0.7303 - recall: 0.1597
# Epoch 21: val_accuracy did not improve from 0.38626
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 46s 139ms/step - accuracy: 0.3416 - auc: 0.9066 - loss: 3.0268 - precision: 0.7391 - recall: 0.1609 - val_accuracy: 0.3313 - val_auc: 0.9158 - val_loss: 2.9825 - val_precision: 0.6495 - val_recall: 0.2122 - learning_rate: 0.0010
# Epoch 22/60
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.3620 - auc: 0.9107 - loss: 2.9925 - precision: 0.7570 - recall: 0.1811
# Epoch 22: val_accuracy did not improve from 0.38626
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 82s 138ms/step - accuracy: 0.3530 - auc: 0.9103 - loss: 2.9993 - precision: 0.7535 - recall: 0.1754 - val_accuracy: 0.3710 - val_auc: 0.9327 - val_loss: 2.8167 - val_precision: 0.7870 - val_recall: 0.2031 - learning_rate: 0.0010
# Epoch 23/60
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.3584 - auc: 0.9048 - loss: 3.0193 - precision: 0.7484 - recall: 0.1725
# Epoch 23: val_accuracy did not improve from 0.38626
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 46s 141ms/step - accuracy: 0.3496 - auc: 0.9078 - loss: 3.0102 - precision: 0.7498 - recall: 0.1719 - val_accuracy: 0.3740 - val_auc: 0.9210 - val_loss: 2.9301 - val_precision: 0.6066 - val_recall: 0.2260 - learning_rate: 0.0010
# Epoch 24/60
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.3628 - auc: 0.9135 - loss: 2.9526 - precision: 0.7905 - recall: 0.1858
# Epoch 24: val_accuracy did not improve from 0.38626
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 45s 137ms/step - accuracy: 0.3549 - auc: 0.9122 - loss: 2.9711 - precision: 0.7696 - recall: 0.1796 - val_accuracy: 0.3405 - val_auc: 0.9090 - val_loss: 3.0328 - val_precision: 0.7638 - val_recall: 0.1481 - learning_rate: 0.0010
# Epoch 25/60
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.3528 - auc: 0.9136 - loss: 2.9833 - precision: 0.7547 - recall: 0.1747
# Epoch 25: val_accuracy did not improve from 0.38626
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 45s 137ms/step - accuracy: 0.3553 - auc: 0.9139 - loss: 2.9663 - precision: 0.7580 - recall: 0.1756 - val_accuracy: 0.3817 - val_auc: 0.9342 - val_loss: 2.7971 - val_precision: 0.7917 - val_recall: 0.2031 - learning_rate: 0.0010
# Epoch 26/60
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.3553 - auc: 0.9115 - loss: 2.9784 - precision: 0.7618 - recall: 0.1733
# Epoch 26: val_accuracy did not improve from 0.38626
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 45s 137ms/step - accuracy: 0.3572 - auc: 0.9116 - loss: 2.9765 - precision: 0.7602 - recall: 0.1735 - val_accuracy: 0.3710 - val_auc: 0.9326 - val_loss: 2.8337 - val_precision: 0.7769 - val_recall: 0.1542 - learning_rate: 0.0010
# Epoch 27/60
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.3621 - auc: 0.9173 - loss: 2.9324 - precision: 0.7709 - recall: 0.1767
# Epoch 27: val_accuracy did not improve from 0.38626
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 45s 138ms/step - accuracy: 0.3620 - auc: 0.9161 - loss: 2.9337 - precision: 0.7707 - recall: 0.1826 - val_accuracy: 0.3679 - val_auc: 0.9236 - val_loss: 2.9168 - val_precision: 0.7089 - val_recall: 0.2305 - learning_rate: 0.0010
# Epoch 28/60
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.3535 - auc: 0.9178 - loss: 2.9456 - precision: 0.7575 - recall: 0.1772
# Epoch 28: val_accuracy did not improve from 0.38626
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 45s 138ms/step - accuracy: 0.3607 - auc: 0.9166 - loss: 2.9470 - precision: 0.7592 - recall: 0.1815 - val_accuracy: 0.3603 - val_auc: 0.9235 - val_loss: 2.9056 - val_precision: 0.7474 - val_recall: 0.2214 - learning_rate: 0.0010
# Epoch 28: early stopping
# Restoring model weights from the end of the best epoch: 18.
# Best val_accuracy: 0.3863
# 2480

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
axes[0].plot(history.history['accuracy'],     lw=2, label='Train')
axes[0].plot(history.history['val_accuracy'], lw=2, label='Val')
axes[0].set_title('Custom CNN — Accuracy', fontsize=13, fontweight='bold')
axes[0].set_xlabel('Epoch'); axes[0].legend(); axes[0].grid(alpha=0.3)
axes[1].plot(history.history['loss'],     lw=2, label='Train')
axes[1].plot(history.history['val_loss'], lw=2, label='Val')
axes[1].set_title('Custom CNN — Loss', fontsize=13, fontweight='bold')
axes[1].set_xlabel('Epoch'); axes[1].legend(); axes[1].grid(alpha=0.3)
plt.tight_layout(); plt.show()

# %%
print("Running streaming predictions on test set …")
y_pred_list = []; y_true_list = []
test_ds.reset()
for batch_x, batch_y in test_ds:
    preds = model.predict_on_batch(batch_x)
    y_pred_list.append(np.argmax(preds,   axis=1))
    y_true_list.append(np.argmax(batch_y, axis=1))
    if len(y_pred_list) >= TEST_STP: break
y_pred = np.concatenate(y_pred_list)
y_true = np.concatenate(y_true_list)
del y_pred_list, y_true_list; gc.collect()
n = min(len(y_pred), len(y_true)); y_pred, y_true = y_pred[:n], y_true[:n]

acc  = accuracy_score (y_true, y_pred)
prec = precision_score(y_true, y_pred, average='weighted', zero_division=0)
rec  = recall_score   (y_true, y_pred, average='weighted', zero_division=0)
f1   = f1_score       (y_true, y_pred, average='weighted', zero_division=0)
print(f"\n  Accuracy  : {acc:.4f}")
print(f"  Precision : {prec:.4f}")
print(f"  Recall    : {rec:.4f}")
print(f"  F1-Score  : {f1:.4f}")
print(f"  Grade     : {'EXCELLENT (>=90%)' if acc>=0.90 else 'GOOD (>=80%)' if acc>=0.80 else 'Needs tuning'}")
print("\n—— Classification Report ——")
print(classification_report(y_true, y_pred, labels=np.arange(len(classes)),
                             target_names=classes, zero_division=0))
# Out:
# Running streaming predictions on test set …
#
#   Accuracy  : 0.3714
#   Precision : 0.3308
#   Recall    : 0.3714
#   F1-Score  : 0.3227
#   Grade     : Needs tuning
#
# —— Classification Report ——
#                      precision    recall  f1-score   support
#
#             Alfalfa       0.00      0.00      0.00         5
#           Asparagus       0.11      0.30      0.16        10
#        Blue Vervain       0.00      0.00      0.00         5
#  Broadleaf Plantain       0.00      0.00      0.00         5
#        Bull Thistle       0.25      0.20      0.22         5
#             Cattail       0.00      0.00      0.00         5
#           Chickweed       0.14      0.47      0.22        15
#             Chicory       1.00      0.40      0.57         5
#            Cleavers       0.00      0.00      0.00         5
#           Coltsfoot       0.00      0.00      0.00         5
#  Common Sow Thistle       0.33      0.10      0.15        10
#       Common Yarrow       0.00      0.00      0.00         5
#          Coneflower       0.67      0.40      0.50         5
#    Creeping Charlie       0.26      0.50      0.34        10
#      Crimson Clover       0.27      0.80      0.40         5
#          Curly Dock       0.12      0.67      0.21        15
#      Daisy Fleabane       0.75      0.51      0.60        77
#          Dandellion       0.65      0.64      0.64       106
# Downy Yellow Violet       0.00      0.00      0.00         5
#          Elderberry       0.33      0.10      0.15        10
#    Evening Primrose       0.00      0.00      0.00         5
#    Fern Leaf Yarrow       0.00      0.00      0.00         5
#    Field Pennycress       0.00      0.00      0.00        10
#            Fireweed       0.25      0.20      0.22         5
#       Forget Me Not       0.00      0.00      0.00         5
#      Garlic Mustard       0.12      0.20      0.15        10
#            Harebell       0.29      0.40      0.33         5
#              Henbit       0.32      0.80      0.45        15
#         Herb Robert       0.00      0.00      0.00         5
#   Japanese Knotweed       0.00      0.00      0.00         5
#        Joe Pye Weed       1.00      0.20      0.33         5
#            Knapweed       0.00      0.00      0.00         5
#               Kudzu       0.00      0.00      0.00         5
#      Lambs Quarters       0.14      0.27      0.18        15
#              Mallow       0.00      0.00      0.00         5
#            Mayapple       0.00      0.00      0.00         5
#         Meadowsweet       0.00      0.00      0.00         5
#        Milk Thistle       0.80      0.80      0.80         5
#             Mullein       0.00      0.00      0.00         5
#   New England Aster       0.00      0.00      0.00         5
#      Partridgeberry       0.00      0.00      0.00         5
#         Peppergrass       0.00      0.00      0.00        15
#        Pickerelweed       0.00      0.00      0.00         5
#      Pineapple Weed       0.00      0.00      0.00         5
# Prickly Pear Cactus       0.00      0.00      0.00         5
#   Purple Deadnettle       0.00      0.00      0.00        10
#    Queen Annes Lace       0.33      0.20      0.25         5
#          Red Clover       0.33      0.20      0.25         5
#        Sheep Sorrel       0.00      0.00      0.00         5
#     Shepherds Purse       0.00      0.00      0.00        10
#       Spring Beauty       0.67      0.40      0.50         5
#           Sunflower       0.50      0.95      0.65        74
#     Supplejack Vine       0.00      0.00      0.00         5
#           Tea Plant       0.00      0.00      0.00         5
#              Teasel       0.00      0.00      0.00         5
#           Toothwort       0.00      0.00      0.00        10
#      Vervain Mallow       0.00      0.00      0.00         5
#       Wild Bee Balm       0.00      0.00      0.00         5
#   Wild Black Cherry       0.00      0.00      0.00         5
#     Wild Grape Vine       0.00      0.00      0.00        10
#           Wild Leek       0.25      0.10      0.14        10
#         Wood Sorrel       0.00      0.00      0.00         5
#
#            accuracy                           0.37       657
#           macro avg       0.16      0.16      0.14       657
#        weighted avg       0.33      0.37      0.32       657

# %%
cm  = confusion_matrix(y_true, y_pred, labels=np.arange(len(classes)))
fsz = max(10, len(classes)//2)
plt.figure(figsize=(fsz, fsz-2))
sns.heatmap(cm, annot=(len(classes)<=20), fmt='d',
            xticklabels=classes, yticklabels=classes, cmap='Blues')
plt.title('Custom CNN — Confusion Matrix', fontsize=14)
plt.ylabel('True Label'); plt.xlabel('Predicted Label')
plt.xticks(rotation=90, fontsize=7); plt.yticks(rotation=0, fontsize=7)
plt.tight_layout(); plt.show()
del y_pred, y_true; gc.collect()
# Out:
# 16930

# %%
model.save(FINAL_PATH)
print(f"Model saved: {FINAL_PATH}")
gc.collect(); tf.keras.backend.clear_session()
# Out:
# Model saved: /content/drive/MyDrive/edible_plants_models/CustomCNN_edible_plants.keras

# %%
# ── Upload ALL saved files to Google Drive ────────────────────────────────
# Uploads: phase1 checkpoint, phase2 checkpoint, final .keras model
# Works from LOCAL machine only. Skipped automatically on Colab.
IS_COLAB = 'google.colab' in sys.modules

if IS_COLAB:
    print("Running on Colab — all files already saved to Drive. Nothing to upload.")
else:
    print("Running locally — uploading all files from saved_models/ to Google Drive …")
    try:
        import subprocess as _sp, sys as _sys
        _sp.check_call([_sys.executable, '-m', 'pip', 'install', 'pydrive2', '-q'])

        from pydrive2.auth import GoogleAuth
        from pydrive2.drive import GoogleDrive

        # One-time browser login (cached after first run)
        gauth = GoogleAuth()
        gauth.LocalWebserverAuth()
        gdrive = GoogleDrive(gauth)

        # Find or create 'edible_plants_models' folder in Drive root
        folder_list = gdrive.ListFile(
            {'q': "title='edible_plants_models' and "
                  "mimeType='application/vnd.google-apps.folder' and "
                  "trashed=false"}
        ).GetList()

        if folder_list:
            folder_id = folder_list[0]['id']
            print(f"Found Drive folder  : edible_plants_models (id={folder_id})")
        else:
            folder = gdrive.CreateFile({
                'title': 'edible_plants_models',
                'mimeType': 'application/vnd.google-apps.folder'
            })
            folder.Upload()
            folder_id = folder['id']
            print(f"Created Drive folder: edible_plants_models (id={folder_id})")

        # Upload every file inside DRIVE_DIR (saved_models/)
        all_files = [f for f in os.listdir(DRIVE_DIR)
                     if os.path.isfile(os.path.join(DRIVE_DIR, f))]

        if not all_files:
            print("No files found in saved_models/ — make sure training completed.")
        else:
            print(f"\nUploading {len(all_files)} file(s):")
            for fname in sorted(all_files):
                local_path = os.path.join(DRIVE_DIR, fname)
                size_mb = os.path.getsize(local_path) / (1024 * 1024)

                # Check if file already exists in Drive folder → update it
                existing = gdrive.ListFile(
                    {'q': f"title='{fname}' and '{folder_id}' in parents and trashed=false"}
                ).GetList()

                if existing:
                    gfile = existing[0]
                    gfile.SetContentFile(local_path)
                    gfile.Upload()
                    print(f"  Updated  {fname:50s}  ({size_mb:.1f} MB)")
                else:
                    gfile = gdrive.CreateFile({
                        'title': fname,
                        'parents': [{'id': folder_id}]
                    })
                    gfile.SetContentFile(local_path)
                    gfile.Upload()
                    print(f"  Uploaded {fname:50s}  ({size_mb:.1f} MB)")

            print("\nAll files uploaded to Drive/edible_plants_models/")
            print("Open modelcomparison.ipynb on Colab to compare all models.")

    except Exception as e:
        print(f"Auto-upload failed: {e}")
        print("\nManual option:")
        print(f"  Go to drive.google.com → My Drive")
        print(f"  Create folder 'edible_plants_models' if it doesn't exist")
        print(f"  Upload all files from: {DRIVE_DIR}")
# Out:
# Running on Colab — all files already saved to Drive. Nothing to upload.
